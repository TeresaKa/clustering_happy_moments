# %%
import gensim
from gensim.test.utils import common_texts
from gensim.models.doc2vec import Doc2Vec, TaggedDocument
from gensim.test.utils import get_tmpfile

import nltk
from nltk.cluster import KMeansClusterer
nltk.download('wordnet')

import pandas as pd
import numpy as np
from collections import Counter
import matplotlib.pyplot as plt
import seaborn as sns
 
from sklearn.model_selection import train_test_split 
from sklearn.cluster import KMeans, AgglomerativeClustering
from scipy.cluster.hierarchy import dendrogram, linkage
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE

import warnings
warnings.filterwarnings("ignore", category=FutureWarning)
warnings.filterwarnings("ignore", category=DeprecationWarning)
# Out:
# [nltk_data] Downloading package wordnet to /home/teresa/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# ### Daten importieren und vorbereiten

# %%
happy = pd.read_csv('happy_preprocessed_onlygroundtruth.csv')
happy.head(1)
# Out:
#    Unnamed: 0   hmid   wid reflection_period  \
# 0           6  40281  2053               24h
#
#                                original_hm  \
# 0  I played a game for about half an hour.
#
#                                 cleaned_hm  modified  num_sentence  \
# 0  I played a game for about half an hour.      True             1
#
#   ground_truth_category predicted_category  ...  \
# 0               leisure            leisure  ...
#
#                                    stemmed  \
# 0   I play a game for about half an hour .
#
#                                         preprocessed age  country gender  \
# 0  ['i', 'play', 'a', 'game', 'for', 'about', 'ha...  35      USA      m
#
#   marital parenthood age_range  relation_age topic
# 0  single          n     30-39  single_30-39     0
#
# [1 rows x 21 columns]

# %%
import string
def text_process(mess):
    """
    Takes in a string of text, then performs the following:
    1. Remove all punctuation
    2. Returns a list of the cleaned text
    """
    # Check characters to see if they are in punctuation
    nopunc = [char for char in mess if char not in string.punctuation]
    # remove commonly occurring words
    LIMIT_WORDS = ['happy', 'day', 'got', 'went', 'today', 'made', 'one', 'two', 'time', 'last', 'first', 'going', 'getting', 'took', 'found', 'lot', 'really', 'saw', 'see', 'month', 'week', 'day', 'yesterday', 'year', 'ago', 'now', 'still', 'since', 'something', 'great', 'good', 'long', 'thing', 'toi', 'without', 'yesteri', '2s', 'toand', 'ing']
    nopunc = [char for char in mess if char not in LIMIT_WORDS]
        
    # Join the characters again to form the string.
    nopunc = ''.join(nopunc)   
    # Now just remove any stopwords

    
    return [word.lower() for word in nopunc.split()]
# Apply to entire happy dataset, column cleaned_hm
happy['preprocessed'] = happy['stemmed'].apply(text_process)
happy.head(1)
# Out:
#    Unnamed: 0   hmid   wid reflection_period  \
# 0           6  40281  2053               24h
#
#                                original_hm  \
# 0  I played a game for about half an hour.
#
#                                 cleaned_hm  modified  num_sentence  \
# 0  I played a game for about half an hour.      True             1
#
#   ground_truth_category predicted_category  length  \
# 0               leisure            leisure       9
#
#                                    stemmed  \
# 0   I play a game for about half an hour .
#
#                                         preprocessed  age country gender  \
# 0  [i, play, a, game, for, about, half, an, hour, .]   35     USA      m
#
#   marital parenthood age_range topic
# 0  single          n     30-39     0

# %%
# happy_datasplit['stemmed_split'] = ''
# for i, row in happy_datasplit.iterrows():
#     happy_datasplit.at[i, 'stemmed_split'] = row.stemmed.split()
# happy_datasplit

# %%
cols = ['ground_truth_category', 'preprocessed']
happy_datasplit = happy[cols]
# for i, row in happy_datasplit.iterrows():
#     print(' '.join(map(str, list(row.preprocessed))))
#     row.preprocessed = ' '.join(row.preprocessed)
happy_datasplit
# Out:
#       ground_truth_category                                       preprocessed
# 0                   leisure  [i, play, a, game, for, about, half, an, hour, .]
# 1                 affection  [when, my, famili, plan, a, abroad, tour, with...
# 2                 affection  [when, my, hous, readi, to, live, with, my, fa...
# 3                   bonding  [when, my, friend, meet, me, today, with, expe...
# 4                 affection  [i, wa, veri, happi, when, my, son, play, with...
# ...                     ...                                                ...
# 14078           achievement  [my, tooth, stop, ach, after, my, dentist, vis...
# 14079             affection           [i, took, a, bath, with, my, husband, .]
# 14080           achievement  [i, got, on, the, scale, in, the, morn, and, i...
# 14081             affection                  [quit, dinner, with, my, wife, .]
# 14082               bonding  [yesterday, even, i, receiv, a, call, from, un...
#
# [14083 rows x 2 columns]

# %%
train_dict = happy_datasplit.groupby('ground_truth_category')['preprocessed'].apply(list).to_dict()
# test_dict = test.groupby('Genre1')['stemmed_split'].apply(list).to_dict()

# %%
train_tagged = {} # Contains clean tagged training data organized by category. To be used for the training corpus.
# test_clean = {} # Contains clean un-tagged training data organized by category.
# test_tagged = {}

offset = 0 # Used for managing IDs of tagged documents
for k, v in train_dict.items():
    train_tagged[k] = [gensim.models.doc2vec.TaggedDocument(doc, [i+offset]) for i, doc in enumerate(v)]
    offset += len(v)
    
# Eventually contains final versions of the training data to actually train the model
train_corpus = [taggeddoc for taggeddoc_list in list(train_tagged.values()) for taggeddoc in taggeddoc_list]
# test_corpus = [taggeddoc for taggeddoc_list in list(test_tagged.values()) for taggeddoc in taggeddoc_list]

# %% [markdown]
# ### Modell vorbereiten und trainieren

# %% [markdown]
# https://tmthyjames.github.io/2018/january/Analyzing-Rap-Lyrics-Using-Word-Vectors/

# %% [markdown]
# #### Parameter-Finetuning

# %%
model = Doc2Vec(size=100,      # Songlängen zwischen 1000 und 5000 Wörtern
                min_count=2,
                window=5,
                epochs=40,
                dm=1)

model.build_vocab(train_corpus)
model.train(train_corpus,
            total_examples=model.corpus_count,
                epochs=model.epochs)

model.save("d2v.model")
print("Model Saved")
# Out:
# /home/teresa/anaconda3/lib/python3.7/site-packages/gensim/models/doc2vec.py:574: UserWarning: The parameter `size` is deprecated, will be removed in 4.0.0, use `vector_size` instead.
#   warnings.warn("The parameter `size` is deprecated, will be removed in 4.0.0, use `vector_size` instead.")
# Model Saved

# %%
# Modell mit Daten ohne Rock und Pop

model=Doc2Vec.load("d2v.model")
print(len(model.docvecs))
# model.wv.vocab
# Out:
# 14083

# %%
model.wv.vocab
# Out:
# {'when': <gensim.models.keyedvectors.Vocab at 0x7f46f0035050>,
#  'i': <gensim.models.keyedvectors.Vocab at 0x7f46f0035f10>,
#  'shift': <gensim.models.keyedvectors.Vocab at 0x7f46f0035610>,
#  'my': <gensim.models.keyedvectors.Vocab at 0x7f46f0035790>,
#  'new': <gensim.models.keyedvectors.Vocab at 0x7f46f0035e90>,
#  'home': <gensim.models.keyedvectors.Vocab at 0x7f46f0035c50>,
#  'bought': <gensim.models.keyedvectors.Vocab at 0x7f46f0035150>,
#  'wed': <gensim.models.keyedvectors.Vocab at 0x7f46f0035110>,
#  'shoe': <gensim.models.keyedvectors.Vocab at 0x7f46fc849390>,
#  '!': <gensim.models.keyedvectors.Vocab at 0x7f46f0053690>,
#  'watch': <gensim.models.keyedvectors.Vocab at 0x7f46f0053ad0>,
#  'arriv': <gensim.models.keyedvectors.Vocab at 0x7f46f0053d50>,
#  'in': <gensim.models.keyedvectors.Vocab at 0x7f46f0053990>,
#  'the': <gensim.models.keyedvectors.Vocab at 0x7f46f00535d0>,
#  'mail': <gensim.models.keyedvectors.Vocab at 0x7f46f0053510>,
#  'start': <gensim.models.keyedvectors.Vocab at 0x7f46f0053cd0>,
#  'trade': <gensim.models.keyedvectors.Vocab at 0x7f46f0053090>,
#  'small': <gensim.models.keyedvectors.Vocab at 0x7f46f0053810>,
#  'time': <gensim.models.keyedvectors.Vocab at 0x7f46f00531d0>,
#  'stock': <gensim.models.keyedvectors.Vocab at 0x7f46f0053250>,
#  'to': <gensim.models.keyedvectors.Vocab at 0x7f46f0053190>,
#  'begin': <gensim.models.keyedvectors.Vocab at 0x7f46f0053210>,
#  'learn': <gensim.models.keyedvectors.Vocab at 0x7f46f0053e50>,
#  '.': <gensim.models.keyedvectors.Vocab at 0x7f46f0053610>,
#  'saw': <gensim.models.keyedvectors.Vocab at 0x7f46f0053450>,
#  'that': <gensim.models.keyedvectors.Vocab at 0x7f46f0053650>,
#  'upload': <gensim.models.keyedvectors.Vocab at 0x7f46f00530d0>,
#  'video': <gensim.models.keyedvectors.Vocab at 0x7f46f0053c90>,
#  'ha': <gensim.models.keyedvectors.Vocab at 0x7f46f00536d0>,
#  'been': <gensim.models.keyedvectors.Vocab at 0x7f46f0053490>,
#  'view': <gensim.models.keyedvectors.Vocab at 0x7f46f0053f10>,
#  'by': <gensim.models.keyedvectors.Vocab at 0x7f46f0053850>,
#  'mani': <gensim.models.keyedvectors.Vocab at 0x7f46f0053c10>,
#  'peopl': <gensim.models.keyedvectors.Vocab at 0x7f46f0053a50>,
#  'made': <gensim.models.keyedvectors.Vocab at 0x7f46f0053290>,
#  'a': <gensim.models.keyedvectors.Vocab at 0x7f46f0053fd0>,
#  'veri': <gensim.models.keyedvectors.Vocab at 0x7f46f0053950>,
#  'high': <gensim.models.keyedvectors.Vocab at 0x7f46f0053f50>,
#  'rank': <gensim.models.keyedvectors.Vocab at 0x7f46f0053110>,
#  'hearthston': <gensim.models.keyedvectors.Vocab at 0x7f46f0053f90>,
#  'recent': <gensim.models.keyedvectors.Vocab at 0x7f46f00539d0>,
#  'after': <gensim.models.keyedvectors.Vocab at 0x7f46f005e350>,
#  'struggl': <gensim.models.keyedvectors.Vocab at 0x7f46f005e810>,
#  'for': <gensim.models.keyedvectors.Vocab at 0x7f46f005e790>,
#  'it': <gensim.models.keyedvectors.Vocab at 0x7f46f005e190>,
#  'got': <gensim.models.keyedvectors.Vocab at 0x7f46f005e490>,
#  'legendari': <gensim.models.keyedvectors.Vocab at 0x7f46f005e110>,
#  'item': <gensim.models.keyedvectors.Vocab at 0x7f46f005e550>,
#  'world': <gensim.models.keyedvectors.Vocab at 0x7f46f005e2d0>,
#  'of': <gensim.models.keyedvectors.Vocab at 0x7f46f005e510>,
#  ',': <gensim.models.keyedvectors.Vocab at 0x7f46f005e150>,
#  'about': <gensim.models.keyedvectors.Vocab at 0x7f46f005ee10>,
#  '3': <gensim.models.keyedvectors.Vocab at 0x7f46f005ed90>,
#  'month': <gensim.models.keyedvectors.Vocab at 0x7f46f005eb90>,
#  'sinc': <gensim.models.keyedvectors.Vocab at 0x7f46f005eb10>,
#  "'ve": <gensim.models.keyedvectors.Vocab at 0x7f46f005e5d0>,
#  'tri': <gensim.models.keyedvectors.Vocab at 0x7f46f005e250>,
#  'one': <gensim.models.keyedvectors.Vocab at 0x7f46f005e9d0>,
#  'comp': <gensim.models.keyedvectors.Vocab at 0x7f46f005e310>,
#  'suit': <gensim.models.keyedvectors.Vocab at 0x7f46f005e450>,
#  'citi': <gensim.models.keyedvectors.Vocab at 0x7f46f005e8d0>,
#  'not': <gensim.models.keyedvectors.Vocab at 0x7f46f005ef50>,
#  'be': <gensim.models.keyedvectors.Vocab at 0x7f46f005e750>,
#  'there': <gensim.models.keyedvectors.Vocab at 0x7f46f005e950>,
#  'while': <gensim.models.keyedvectors.Vocab at 0x7f46f005ec90>,
#  'complet': <gensim.models.keyedvectors.Vocab at 0x7f46f005ee50>,
#  'unexpect': <gensim.models.keyedvectors.Vocab at 0x7f46f005ed50>,
#  'have': <gensim.models.keyedvectors.Vocab at 0x7f46f005ed10>,
#  'success': <gensim.models.keyedvectors.Vocab at 0x7f46f005e7d0>,
#  'project': <gensim.models.keyedvectors.Vocab at 0x7f46f005e650>,
#  'and': <gensim.models.keyedvectors.Vocab at 0x7f46eff62750>,
#  'client': <gensim.models.keyedvectors.Vocab at 0x7f46eff62c10>,
#  'appreci': <gensim.models.keyedvectors.Vocab at 0x7f46eff62290>,
#  'me': <gensim.models.keyedvectors.Vocab at 0x7f46eff62f50>,
#  'much': <gensim.models.keyedvectors.Vocab at 0x7f46eff62550>,
#  'good': <gensim.models.keyedvectors.Vocab at 0x7f46eff620d0>,
#  'increment': <gensim.models.keyedvectors.Vocab at 0x7f46eff62150>,
#  'salari': <gensim.models.keyedvectors.Vocab at 0x7f46eff62810>,
#  'friend': <gensim.models.keyedvectors.Vocab at 0x7f46eff62090>,
#  'elect': <gensim.models.keyedvectors.Vocab at 0x7f46eff62510>,
#  'as': <gensim.models.keyedvectors.Vocab at 0x7f46eff62950>,
#  'presid': <gensim.models.keyedvectors.Vocab at 0x7f46eff62b90>,
#  'our': <gensim.models.keyedvectors.Vocab at 0x7f46d6f3c250>,
#  'art': <gensim.models.keyedvectors.Vocab at 0x7f46d5cbea10>,
#  'club': <gensim.models.keyedvectors.Vocab at 0x7f46d6f2de90>,
#  'won': <gensim.models.keyedvectors.Vocab at 0x7f46d6f2df10>,
#  'price': <gensim.models.keyedvectors.Vocab at 0x7f46d6f2d610>,
#  'money': <gensim.models.keyedvectors.Vocab at 0x7f46d6f2d890>,
#  'ten': <gensim.models.keyedvectors.Vocab at 0x7f46eff62910>,
#  'thousand': <gensim.models.keyedvectors.Vocab at 0x7f46eff62ad0>,
#  'can': <gensim.models.keyedvectors.Vocab at 0x7f46eff62f10>,
#  'rememb': <gensim.models.keyedvectors.Vocab at 0x7f46eff62a90>,
#  'happi': <gensim.models.keyedvectors.Vocab at 0x7f46eff62cd0>,
#  'event': <gensim.models.keyedvectors.Vocab at 0x7f46eff62450>,
#  'life': <gensim.models.keyedvectors.Vocab at 0x7f46eff629d0>,
#  'out': <gensim.models.keyedvectors.Vocab at 0x7f46eff62390>,
#  'those': <gensim.models.keyedvectors.Vocab at 0x7f46eff625d0>,
#  'would': <gensim.models.keyedvectors.Vocab at 0x7f46eff62710>,
#  'like': <gensim.models.keyedvectors.Vocab at 0x7f46eff628d0>,
#  'talk': <gensim.models.keyedvectors.Vocab at 0x7f46eff62a10>,
#  'still': <gensim.models.keyedvectors.Vocab at 0x7f46eff62790>,
#  'vividli': <gensim.models.keyedvectors.Vocab at 0x7f46eff62bd0>,
#  'regard': <gensim.models.keyedvectors.Vocab at 0x7f46eff62e10>,
#  'board': <gensim.models.keyedvectors.Vocab at 0x7f46eff62dd0>,
#  'exam': <gensim.models.keyedvectors.Vocab at 0x7f46eff62c90>,
#  'moment': <gensim.models.keyedvectors.Vocab at 0x7f46eff62650>,
#  'heard': <gensim.models.keyedvectors.Vocab at 0x7f46eff67590>,
#  'had': <gensim.models.keyedvectors.Vocab at 0x7f46eff67690>,
#  'award': <gensim.models.keyedvectors.Vocab at 0x7f46eff67950>,
#  'scholarship': <gensim.models.keyedvectors.Vocab at 0x7f46eff677d0>,
#  'base': <gensim.models.keyedvectors.Vocab at 0x7f46eff67650>,
#  'on': <gensim.models.keyedvectors.Vocab at 0x7f46eff67ed0>,
#  'perform': <gensim.models.keyedvectors.Vocab at 0x7f46eff67fd0>,
#  'becam': <gensim.models.keyedvectors.Vocab at 0x7f46eff67150>,
#  'happiest': <gensim.models.keyedvectors.Vocab at 0x7f46eff67190>,
#  'man': <gensim.models.keyedvectors.Vocab at 0x7f46eff67290>,
#  'thi': <gensim.models.keyedvectors.Vocab at 0x7f46eff676d0>,
#  'wa': <gensim.models.keyedvectors.Vocab at 0x7f46eff67350>,
#  'inde': <gensim.models.keyedvectors.Vocab at 0x7f46eff673d0>,
#  'is': <gensim.models.keyedvectors.Vocab at 0x7f46eff67bd0>,
#  'someth': <gensim.models.keyedvectors.Vocab at 0x7f46eff67850>,
#  'look': <gensim.models.keyedvectors.Vocab at 0x7f46eff67b50>,
#  'forward': <gensim.models.keyedvectors.Vocab at 0x7f46eff67390>,
#  'achiev': <gensim.models.keyedvectors.Vocab at 0x7f46eff67210>,
#  'news': <gensim.models.keyedvectors.Vocab at 0x7f46eff67890>,
#  'parent': <gensim.models.keyedvectors.Vocab at 0x7f46eff67610>,
#  'quit': <gensim.models.keyedvectors.Vocab at 0x7f46eff67b90>,
#  'proud': <gensim.models.keyedvectors.Vocab at 0x7f46eff67ad0>,
#  'laptop': <gensim.models.keyedvectors.Vocab at 0x7f46eff67050>,
#  'work': <gensim.models.keyedvectors.Vocab at 0x7f46eff67f10>,
#  'realli': <gensim.models.keyedvectors.Vocab at 0x7f46eff67a50>,
#  'well': <gensim.models.keyedvectors.Vocab at 0x7f46eff67b10>,
#  'person': <gensim.models.keyedvectors.Vocab at 0x7f46eff6d390>,
#  'record': <gensim.models.keyedvectors.Vocab at 0x7f46eff6dcd0>,
#  'bench': <gensim.models.keyedvectors.Vocab at 0x7f46eff6ded0>,
#  'press': <gensim.models.keyedvectors.Vocab at 0x7f46eff6d110>,
#  'promot': <gensim.models.keyedvectors.Vocab at 0x7f46eff6d490>,
#  'at': <gensim.models.keyedvectors.Vocab at 0x7f46eff6d850>,
#  'increas': <gensim.models.keyedvectors.Vocab at 0x7f46eff6dc10>,
#  'deadlift': <gensim.models.keyedvectors.Vocab at 0x7f46eff6d310>,
#  'win': <gensim.models.keyedvectors.Vocab at 0x7f46eff6d450>,
#  'sport': <gensim.models.keyedvectors.Vocab at 0x7f46eff6d9d0>,
#  'team': <gensim.models.keyedvectors.Vocab at 0x7f46eff6da10>,
#  'tornado': <gensim.models.keyedvectors.Vocab at 0x7f46eff6da50>,
#  'came': <gensim.models.keyedvectors.Vocab at 0x7f46eff6d8d0>,
#  'through': <gensim.models.keyedvectors.Vocab at 0x7f46eff6d810>,
#  'area': <gensim.models.keyedvectors.Vocab at 0x7f46eff6db90>,
#  'monday': <gensim.models.keyedvectors.Vocab at 0x7f46eff6dfd0>,
#  'so': <gensim.models.keyedvectors.Vocab at 0x7f46eff6df50>,
#  'some': <gensim.models.keyedvectors.Vocab at 0x7f46eff6de10>,
#  'tree': <gensim.models.keyedvectors.Vocab at 0x7f46eff6d090>,
#  'down': <gensim.models.keyedvectors.Vocab at 0x7f46eff6d3d0>,
#  'properti': <gensim.models.keyedvectors.Vocab at 0x7f46eff6d0d0>,
#  'spent': <gensim.models.keyedvectors.Vocab at 0x7f46eff6d710>,
#  'most': <gensim.models.keyedvectors.Vocab at 0x7f46eff6d910>,
#  'afternoon': <gensim.models.keyedvectors.Vocab at 0x7f46eff6d210>,
#  'with': <gensim.models.keyedvectors.Vocab at 0x7f46eff6df10>,
#  'chainsaw': <gensim.models.keyedvectors.Vocab at 0x7f46eff6d5d0>,
#  'now': <gensim.models.keyedvectors.Vocab at 0x7f46eff6d1d0>,
#  'clean': <gensim.models.keyedvectors.Vocab at 0x7f46eff6dbd0>,
#  'yard': <gensim.models.keyedvectors.Vocab at 0x7f46eff6d950>,
#  'next': <gensim.models.keyedvectors.Vocab at 0x7f46eff6d590>,
#  'winter': <gensim.models.keyedvectors.Vocab at 0x7f46eff6d250>,
#  'part-tim': <gensim.models.keyedvectors.Vocab at 0x7f46eff77e90>,
#  'job': <gensim.models.keyedvectors.Vocab at 0x7f46eff77a90>,
#  'part': <gensim.models.keyedvectors.Vocab at 0x7f46eff77490>,
#  'loan': <gensim.models.keyedvectors.Vocab at 0x7f46eff77e50>,
#  'assign': <gensim.models.keyedvectors.Vocab at 0x7f46eff77790>,
#  'help': <gensim.models.keyedvectors.Vocab at 0x7f46eff77fd0>,
#  'colleagu': <gensim.models.keyedvectors.Vocab at 0x7f46eff77210>,
#  'an': <gensim.models.keyedvectors.Vocab at 0x7f46eff77410>,
#  'cash': <gensim.models.keyedvectors.Vocab at 0x7f46eff775d0>,
#  'reward': <gensim.models.keyedvectors.Vocab at 0x7f46eff77750>,
#  'involv': <gensim.models.keyedvectors.Vocab at 0x7f46eff77d50>,
#  'manag': <gensim.models.keyedvectors.Vocab at 0x7f46eff77890>,
#  'live': <gensim.models.keyedvectors.Vocab at 0x7f46eff77910>,
#  'room': <gensim.models.keyedvectors.Vocab at 0x7f46eff777d0>,
#  'week': <gensim.models.keyedvectors.Vocab at 0x7f46eff77690>,
#  'do': <gensim.models.keyedvectors.Vocab at 0x7f46eff77e10>,
#  'exercis': <gensim.models.keyedvectors.Vocab at 0x7f46eff77c10>,
#  'score': <gensim.models.keyedvectors.Vocab at 0x7f46eff77c90>,
#  'cellphon': <gensim.models.keyedvectors.Vocab at 0x7f46eff77190>,
#  'ebay': <gensim.models.keyedvectors.Vocab at 0x7f46eff77310>,
#  'auction': <gensim.models.keyedvectors.Vocab at 0x7f46eff77050>,
#  'sold': <gensim.models.keyedvectors.Vocab at 0x7f46eff77d90>,
#  'right': <gensim.models.keyedvectors.Vocab at 0x7f46eff77590>,
#  'away': <gensim.models.keyedvectors.Vocab at 0x7f46eff77850>,
#  'final': <gensim.models.keyedvectors.Vocab at 0x7f46eff77610>,
#  'paid': <gensim.models.keyedvectors.Vocab at 0x7f46eff77d10>,
#  'off': <gensim.models.keyedvectors.Vocab at 0x7f46eff771d0>,
#  'half': <gensim.models.keyedvectors.Vocab at 0x7f46eff77110>,
#  'car': <gensim.models.keyedvectors.Vocab at 0x7f46eff776d0>,
#  'run': <gensim.models.keyedvectors.Vocab at 0x7f46eff772d0>,
#  'dog': <gensim.models.keyedvectors.Vocab at 0x7f46eff77f90>,
#  'even': <gensim.models.keyedvectors.Vocab at 0x7f46f0049890>,
#  'realiz': <gensim.models.keyedvectors.Vocab at 0x7f46f0049590>,
#  'beat': <gensim.models.keyedvectors.Vocab at 0x7f46f0049350>,
#  'mile': <gensim.models.keyedvectors.Vocab at 0x7f46f0049a90>,
#  'again': <gensim.models.keyedvectors.Vocab at 0x7f46f0049c10>,
#  'last': <gensim.models.keyedvectors.Vocab at 0x7f46f0049850>,
#  'without': <gensim.models.keyedvectors.Vocab at 0x7f46f0049b90>,
#  'finish': <gensim.models.keyedvectors.Vocab at 0x7f46f0049510>,
#  'first': <gensim.models.keyedvectors.Vocab at 0x7f46f00495d0>,
#  'websit': <gensim.models.keyedvectors.Vocab at 0x7f46f0049110>,
#  'develop': <gensim.models.keyedvectors.Vocab at 0x7f46f0049f10>,
#  'from': <gensim.models.keyedvectors.Vocab at 0x7f46f0049410>,
#  'scratch': <gensim.models.keyedvectors.Vocab at 0x7f46f00494d0>,
#  'use': <gensim.models.keyedvectors.Vocab at 0x7f46f0049ad0>,
#  '&': <gensim.models.keyedvectors.Vocab at 0x7f46f0049910>,
#  'take': <gensim.models.keyedvectors.Vocab at 0x7f46f0049e90>,
#  'food': <gensim.models.keyedvectors.Vocab at 0x7f46f0049dd0>,
#  'contest': <gensim.models.keyedvectors.Vocab at 0x7f46f0049990>,
#  'conduct': <gensim.models.keyedvectors.Vocab at 0x7f46f0049150>,
#  'local': <gensim.models.keyedvectors.Vocab at 0x7f46f0049790>,
#  'group': <gensim.models.keyedvectors.Vocab at 0x7f46f0049210>,
#  'page': <gensim.models.keyedvectors.Vocab at 0x7f46f0049f90>,
#  'voucher': <gensim.models.keyedvectors.Vocab at 0x7f46f0049550>,
#  'two': <gensim.models.keyedvectors.Vocab at 0x7f46f0049a50>,
#  'expens': <gensim.models.keyedvectors.Vocab at 0x7f46f0049690>,
#  'restaur': <gensim.models.keyedvectors.Vocab at 0x7f46f0049d90>,
#  'just': <gensim.models.keyedvectors.Vocab at 0x7f46f0049fd0>,
#  'ca': <gensim.models.keyedvectors.Vocab at 0x7f46eff83ad0>,
#  "n't": <gensim.models.keyedvectors.Vocab at 0x7f46eff831d0>,
#  'believ': <gensim.models.keyedvectors.Vocab at 0x7f46eff83e10>,
#  'luck': <gensim.models.keyedvectors.Vocab at 0x7f46eff83710>,
#  'get': <gensim.models.keyedvectors.Vocab at 0x7f46eff836d0>,
#  'all': <gensim.models.keyedvectors.Vocab at 0x7f46eff83dd0>,
#  'financi': <gensim.models.keyedvectors.Vocab at 0x7f46eff83690>,
#  'troubl': <gensim.models.keyedvectors.Vocab at 0x7f46eff83890>,
#  'feel': <gensim.models.keyedvectors.Vocab at 0x7f46eff830d0>,
#  'relax': <gensim.models.keyedvectors.Vocab at 0x7f46eff83410>,
#  'abl': <gensim.models.keyedvectors.Vocab at 0x7f46eff83050>,
#  'keep': <gensim.models.keyedvectors.Vocab at 0x7f46eff83450>,
#  'up': <gensim.models.keyedvectors.Vocab at 0x7f46eff83590>,
#  'entir': <gensim.models.keyedvectors.Vocab at 0x7f46eff83290>,
#  'tape': <gensim.models.keyedvectors.Vocab at 0x7f46eff83a90>,
#  'wife': <gensim.models.keyedvectors.Vocab at 0x7f46eff83b90>,
#  'rais': <gensim.models.keyedvectors.Vocab at 0x7f46eff83bd0>,
#  'her': <gensim.models.keyedvectors.Vocab at 0x7f46eff839d0>,
#  'substanti': <gensim.models.keyedvectors.Vocab at 0x7f46eff833d0>,
#  'found': <gensim.models.keyedvectors.Vocab at 0x7f46eff83510>,
#  'way': <gensim.models.keyedvectors.Vocab at 0x7f46eff83950>,
#  'game': <gensim.models.keyedvectors.Vocab at 0x7f46eff83cd0>,
#  '10': <gensim.models.keyedvectors.Vocab at 0x7f46eff83d90>,
#  'which': <gensim.models.keyedvectors.Vocab at 0x7f46eff83850>,
#  'save': <gensim.models.keyedvectors.Vocab at 0x7f46eff83190>,
#  'long': <gensim.models.keyedvectors.Vocab at 0x7f46eff83910>,
#  'today': <gensim.models.keyedvectors.Vocab at 0x7f46eff83b50>,
#  'receiv': <gensim.models.keyedvectors.Vocab at 0x7f46f0c7a250>,
#  'done': <gensim.models.keyedvectors.Vocab at 0x7f46f0c7a6d0>,
#  'april': <gensim.models.keyedvectors.Vocab at 0x7f46f0c7ab90>,
#  'releas': <gensim.models.keyedvectors.Vocab at 0x7f46f0c7a050>,
#  'report': <gensim.models.keyedvectors.Vocab at 0x7f46f0c7a890>,
#  'nearli': <gensim.models.keyedvectors.Vocab at 0x7f46f0c7a5d0>,
#  '25': <gensim.models.keyedvectors.Vocab at 0x7f46f0c7a7d0>,
#  'day': <gensim.models.keyedvectors.Vocab at 0x7f46f0c7a8d0>,
#  'hi': <gensim.models.keyedvectors.Vocab at 0x7f46f0c7a090>,
#  'he': <gensim.models.keyedvectors.Vocab at 0x7f46f0c7a290>,
#  'treat': <gensim.models.keyedvectors.Vocab at 0x7f46f0c7a490>,
#  'major': <gensim.models.keyedvectors.Vocab at 0x7f46f0c7a1d0>,
#  'felt': <gensim.models.keyedvectors.Vocab at 0x7f46f0c7a610>,
#  'dine': <gensim.models.keyedvectors.Vocab at 0x7f46f0c7ac50>,
#  'may': <gensim.models.keyedvectors.Vocab at 0x7f46f0c7ad50>,
#  'see': <gensim.models.keyedvectors.Vocab at 0x7f46f0c7ab50>,
#  'call': <gensim.models.keyedvectors.Vocab at 0x7f46f0c7a310>,
#  'congratul': <gensim.models.keyedvectors.Vocab at 0x7f46f0c7add0>,
#  'brought': <gensim.models.keyedvectors.Vocab at 0x7f46f0c7acd0>,
#  'mobil': <gensim.models.keyedvectors.Vocab at 0x7f46f0c7a990>,
#  'lost': <gensim.models.keyedvectors.Vocab at 0x7f46f0c7a950>,
#  'befor': <gensim.models.keyedvectors.Vocab at 0x7f46f0c7ae10>,
#  'ticket': <gensim.models.keyedvectors.Vocab at 0x7f46f0c7aa50>,
#  'hous': <gensim.models.keyedvectors.Vocab at 0x7f46f0c7a150>,
#  'chore': <gensim.models.keyedvectors.Vocab at 0x7f46f0c7a810>,
#  'earli': <gensim.models.keyedvectors.Vocab at 0x7f46f0c7afd0>,
#  'packag': <gensim.models.keyedvectors.Vocab at 0x7f46f0c7a690>,
#  'wait': <gensim.models.keyedvectors.Vocab at 0x7f46f0c7a790>,
#  'window': <gensim.models.keyedvectors.Vocab at 0x7f46f0c73b90>,
#  'purchas': <gensim.models.keyedvectors.Vocab at 0x7f46f0c731d0>,
#  'furnitur': <gensim.models.keyedvectors.Vocab at 0x7f46f0c73190>,
#  'bedroom': <gensim.models.keyedvectors.Vocab at 0x7f46f0c73310>,
#  'move': <gensim.models.keyedvectors.Vocab at 0x7f46f0c73390>,
#  'lot': <gensim.models.keyedvectors.Vocab at 0x7f46f0c73fd0>,
#  'into': <gensim.models.keyedvectors.Vocab at 0x7f46f0c73950>,
#  'storag': <gensim.models.keyedvectors.Vocab at 0x7f46f0c73a10>,
#  'facil': <gensim.models.keyedvectors.Vocab at 0x7f46f0c73710>,
#  'onlin': <gensim.models.keyedvectors.Vocab at 0x7f46f0c738d0>,
#  'raffl': <gensim.models.keyedvectors.Vocab at 0x7f46f0c73610>,
#  'repaint': <gensim.models.keyedvectors.Vocab at 0x7f46f0c73f90>,
#  'need': <gensim.models.keyedvectors.Vocab at 0x7f46f0c737d0>,
#  'repair': <gensim.models.keyedvectors.Vocab at 0x7f46f0c73ed0>,
#  'phone': <gensim.models.keyedvectors.Vocab at 0x7f46f0c73ad0>,
#  'more': <gensim.models.keyedvectors.Vocab at 0x7f46f0c73a50>,
#  'freedom': <gensim.models.keyedvectors.Vocab at 0x7f46f0c739d0>,
#  'went': <gensim.models.keyedvectors.Vocab at 0x7f46f0c73590>,
#  'casino': <gensim.models.keyedvectors.Vocab at 0x7f46f0c73450>,
#  '700': <gensim.models.keyedvectors.Vocab at 0x7f46f0c730d0>,
#  '$': <gensim.models.keyedvectors.Vocab at 0x7f46f0c73b10>,
#  'tv': <gensim.models.keyedvectors.Vocab at 0x7f46f0c73890>,
#  'pair': <gensim.models.keyedvectors.Vocab at 0x7f46f0c73f50>,
#  'fix': <gensim.models.keyedvectors.Vocab at 0x7f46f0c73090>,
#  'problem': <gensim.models.keyedvectors.Vocab at 0x7f46f0c73110>,
#  'wash': <gensim.models.keyedvectors.Vocab at 0x7f46f0c732d0>,
#  'machin': <gensim.models.keyedvectors.Vocab at 0x7f46f0c73a90>,
#  'than': <gensim.models.keyedvectors.Vocab at 0x7f46f0c73dd0>,
#  'expect': <gensim.models.keyedvectors.Vocab at 0x7f46f0c733d0>,
#  'return': <gensim.models.keyedvectors.Vocab at 0x7f46f0c73e50>,
#  'invest': <gensim.models.keyedvectors.Vocab at 0x7f473fc45050>,
#  'number': <gensim.models.keyedvectors.Vocab at 0x7f46f0023e90>,
#  'pass': <gensim.models.keyedvectors.Vocab at 0x7f46f0023a10>,
#  'distinct': <gensim.models.keyedvectors.Vocab at 0x7f46f00231d0>,
#  'certif': <gensim.models.keyedvectors.Vocab at 0x7f46f0023490>,
#  'cours': <gensim.models.keyedvectors.Vocab at 0x7f46f0023f50>,
#  'profit': <gensim.models.keyedvectors.Vocab at 0x7f46f00236d0>,
#  'busi': <gensim.models.keyedvectors.Vocab at 0x7f46f00232d0>,
#  "'s": <gensim.models.keyedvectors.Vocab at 0x7f46f0023650>,
#  'sale': <gensim.models.keyedvectors.Vocab at 0x7f46f0023890>,
#  'player': <gensim.models.keyedvectors.Vocab at 0x7f46f0023b90>,
#  'server': <gensim.models.keyedvectors.Vocab at 0x7f46f0023950>,
#  'apart': <gensim.models.keyedvectors.Vocab at 0x7f46f0023910>,
#  'larg': <gensim.models.keyedvectors.Vocab at 0x7f46f0023d10>,
#  'passport': <gensim.models.keyedvectors.Vocab at 0x7f46f0023cd0>,
#  'applic': <gensim.models.keyedvectors.Vocab at 0x7f46f0023790>,
#  '1st': <gensim.models.keyedvectors.Vocab at 0x7f46f0023dd0>,
#  'paycheck': <gensim.models.keyedvectors.Vocab at 0x7f46f0023ed0>,
#  'yesterday': <gensim.models.keyedvectors.Vocab at 0x7f46f0023e50>,
#  'measur': <gensim.models.keyedvectors.Vocab at 0x7f46f0023bd0>,
#  'weight': <gensim.models.keyedvectors.Vocab at 0x7f46f0023190>,
#  '1': <gensim.models.keyedvectors.Vocab at 0x7f46f0023c90>,
#  'pound': <gensim.models.keyedvectors.Vocab at 0x7f46f0023110>,
#  'earlier': <gensim.models.keyedvectors.Vocab at 0x7f46f00234d0>,
#  'lift': <gensim.models.keyedvectors.Vocab at 0x7f46f0023ad0>,
#  'resid': <gensim.models.keyedvectors.Vocab at 0x7f46f0023c10>,
#  'order': <gensim.models.keyedvectors.Vocab at 0x7f46f0023a50>,
#  'annual': <gensim.models.keyedvectors.Vocab at 0x7f46f0023150>,
#  'letter': <gensim.models.keyedvectors.Vocab at 0x7f46f0023410>,
#  'employ': <gensim.models.keyedvectors.Vocab at 0x7f46f00233d0>,
#  'sim': <gensim.models.keyedvectors.Vocab at 0x7f46f0023510>,
#  'card': <gensim.models.keyedvectors.Vocab at 0x7f46f0023250>,
#  'network': <gensim.models.keyedvectors.Vocab at 0x7f46efdd7710>,
#  'oper': <gensim.models.keyedvectors.Vocab at 0x7f46efdd7290>,
#  'huge': <gensim.models.keyedvectors.Vocab at 0x7f46efdd7190>,
#  'demand': <gensim.models.keyedvectors.Vocab at 0x7f46efdd7790>,
#  '6': <gensim.models.keyedvectors.Vocab at 0x7f46efdd7350>,
#  'acknowledg': <gensim.models.keyedvectors.Vocab at 0x7f46efdd7d90>,
#  'offici': <gensim.models.keyedvectors.Vocab at 0x7f46efdd7e90>,
#  'meet': <gensim.models.keyedvectors.Vocab at 0x7f46efdd7450>,
#  'organ': <gensim.models.keyedvectors.Vocab at 0x7f46efdd7c50>,
#  'verbal': <gensim.models.keyedvectors.Vocab at 0x7f46efdd7d50>,
#  'commun': <gensim.models.keyedvectors.Vocab at 0x7f46efdd7f10>,
#  'will': <gensim.models.keyedvectors.Vocab at 0x7f46efdd75d0>,
#  'transfer': <gensim.models.keyedvectors.Vocab at 0x7f46efdd70d0>,
#  'locat': <gensim.models.keyedvectors.Vocab at 0x7f46efdd7250>,
#  '(': <gensim.models.keyedvectors.Vocab at 0x7f46efdd7dd0>,
#  'carrier': <gensim.models.keyedvectors.Vocab at 0x7f46efdd7bd0>,
#  ')': <gensim.models.keyedvectors.Vocab at 0x7f46efdd7f50>,
#  'unlimit': <gensim.models.keyedvectors.Vocab at 0x7f46efdd7b50>,
#  'voic': <gensim.models.keyedvectors.Vocab at 0x7f46efdd7fd0>,
#  'data': <gensim.models.keyedvectors.Vocab at 0x7f46efdd7ed0>,
#  'free': <gensim.models.keyedvectors.Vocab at 0x7f46efdd78d0>,
#  '.it': <gensim.models.keyedvectors.Vocab at 0x7f46efdd7ad0>,
#  'level.it': <gensim.models.keyedvectors.Vocab at 0x7f46efdd7d10>,
#  'support': <gensim.models.keyedvectors.Vocab at 0x7f46efdd7a10>,
#  'due': <gensim.models.keyedvectors.Vocab at 0x7f46efdd7390>,
#  'memori': <gensim.models.keyedvectors.Vocab at 0x7f46efdd7590>,
#  'career.i': <gensim.models.keyedvectors.Vocab at 0x7f46efdd7750>,
#  'satisfi': <gensim.models.keyedvectors.Vocab at 0x7f46efdd74d0>,
#  'am': <gensim.models.keyedvectors.Vocab at 0x7f46efdd7050>,
#  'organis': <gensim.models.keyedvectors.Vocab at 0x7f46efdd71d0>,
#  'plan': <gensim.models.keyedvectors.Vocab at 0x7f46efdd7090>,
#  'tour': <gensim.models.keyedvectors.Vocab at 0x7f46efdc4890>,
#  'travel': <gensim.models.keyedvectors.Vocab at 0x7f46efdc46d0>,
#  'unforgett': <gensim.models.keyedvectors.Vocab at 0x7f46efdc4b50>,
#  'then': <gensim.models.keyedvectors.Vocab at 0x7f46efdc4850>,
#  'we': <gensim.models.keyedvectors.Vocab at 0x7f46efdc4d50>,
#  'pari': <gensim.models.keyedvectors.Vocab at 0x7f46efdc45d0>,
#  'dream': <gensim.models.keyedvectors.Vocab at 0x7f46efdc4a50>,
#  'tourist': <gensim.models.keyedvectors.Vocab at 0x7f46efdc43d0>,
#  'place': <gensim.models.keyedvectors.Vocab at 0x7f46efdc4710>,
#  'offic': <gensim.models.keyedvectors.Vocab at 0x7f46efdc4c10>,
#  'are': <gensim.models.keyedvectors.Vocab at 0x7f46efdc4bd0>,
#  'enjoy': <gensim.models.keyedvectors.Vocab at 0x7f46efdc4b90>,
#  'togeth': <gensim.models.keyedvectors.Vocab at 0x7f46efdc4390>,
#  'favour': <gensim.models.keyedvectors.Vocab at 0x7f46efdc4110>,
#  'excit': <gensim.models.keyedvectors.Vocab at 0x7f46efdc4210>,
#  'supervisor': <gensim.models.keyedvectors.Vocab at 0x7f46efdc4b10>,
#  'surpris': <gensim.models.keyedvectors.Vocab at 0x7f46efdc4090>,
#  'alway': <gensim.models.keyedvectors.Vocab at 0x7f46efdc4250>,
#  'go': <gensim.models.keyedvectors.Vocab at 0x7f46efdc4fd0>,
#  'properli': <gensim.models.keyedvectors.Vocab at 0x7f46efdc4150>,
#  'accur': <gensim.models.keyedvectors.Vocab at 0x7f46efdc4ed0>,
#  'but': <gensim.models.keyedvectors.Vocab at 0x7f46efdc2a10>,
#  'think': <gensim.models.keyedvectors.Vocab at 0x7f46efdc2150>,
#  'fortun': <gensim.models.keyedvectors.Vocab at 0x7f46efdc2cd0>,
#  'boss': <gensim.models.keyedvectors.Vocab at 0x7f46efdc2e50>,
#  'nobodi': <gensim.models.keyedvectors.Vocab at 0x7f46efdc2d10>,
#  'cabin': <gensim.models.keyedvectors.Vocab at 0x7f46efdc2c10>,
#  'shock': <gensim.models.keyedvectors.Vocab at 0x7f46efdc2890>,
#  'anoth': <gensim.models.keyedvectors.Vocab at 0x7f46efdc2110>,
#  'around': <gensim.models.keyedvectors.Vocab at 0x7f46efdc2b90>,
#  'calm': <gensim.models.keyedvectors.Vocab at 0x7f46efdc20d0>,
#  'dark': <gensim.models.keyedvectors.Vocab at 0x7f46efdc2810>,
#  'turn': <gensim.models.keyedvectors.Vocab at 0x7f46efdc25d0>,
#  'light': <gensim.models.keyedvectors.Vocab at 0x7f46efdc2f10>,
#  'surprisingli': <gensim.models.keyedvectors.Vocab at 0x7f46efdc2dd0>,
#  'they': <gensim.models.keyedvectors.Vocab at 0x7f46efdc2610>,
#  'give': <gensim.models.keyedvectors.Vocab at 0x7f46efdc2490>,
#  'sound': <gensim.models.keyedvectors.Vocab at 0x7f46efdc22d0>,
#  'thrill': <gensim.models.keyedvectors.Vocab at 0x7f46efdc2250>,
#  'slow': <gensim.models.keyedvectors.Vocab at 0x7f46efdc2650>,
#  'cook': <gensim.models.keyedvectors.Vocab at 0x7f46efdc2950>,
#  'chuck': <gensim.models.keyedvectors.Vocab at 0x7f46efdc2350>,
#  'roast': <gensim.models.keyedvectors.Vocab at 0x7f46efdc2ed0>,
#  'stove': <gensim.models.keyedvectors.Vocab at 0x7f46efdc26d0>,
#  'great': <gensim.models.keyedvectors.Vocab at 0x7f46efdc24d0>,
#  'employe': <gensim.models.keyedvectors.Vocab at 0x7f46efdc23d0>,
#  'orient': <gensim.models.keyedvectors.Vocab at 0x7f46efdc2190>,
#  'respons': <gensim.models.keyedvectors.Vocab at 0x7f46f0c81450>,
#  'nhl': <gensim.models.keyedvectors.Vocab at 0x7f46f0c81710>,
#  'round': <gensim.models.keyedvectors.Vocab at 0x7f46f0c81790>,
#  'playoff': <gensim.models.keyedvectors.Vocab at 0x7f46f0c81850>,
#  'seri': <gensim.models.keyedvectors.Vocab at 0x7f46f0c81ad0>,
#  'morn': <gensim.models.keyedvectors.Vocab at 0x7f46f0c81410>,
#  '200': <gensim.models.keyedvectors.Vocab at 0x7f46f0c818d0>,
#  'race': <gensim.models.keyedvectors.Vocab at 0x7f46f0c81490>,
#  'fastest': <gensim.models.keyedvectors.Vocab at 0x7f46f0c81e90>,
#  'announc': <gensim.models.keyedvectors.Vocab at 0x7f46f0c81310>,
#  'valuabl': <gensim.models.keyedvectors.Vocab at 0x7f46f0c81910>,
#  'compani': <gensim.models.keyedvectors.Vocab at 0x7f46f0c81610>,
#  'function': <gensim.models.keyedvectors.Vocab at 0x7f46f0c81bd0>,
#  'year': <gensim.models.keyedvectors.Vocab at 0x7f46f0c81350>,
#  'co-work': <gensim.models.keyedvectors.Vocab at 0x7f46f0c81ed0>,
#  'glad': <gensim.models.keyedvectors.Vocab at 0x7f46f0c81390>,
#  'till': <gensim.models.keyedvectors.Vocab at 0x7f46f0c81090>,
#  '2': <gensim.models.keyedvectors.Vocab at 0x7f46f0c81050>,
#  'kg': <gensim.models.keyedvectors.Vocab at 0x7f46f0c819d0>,
#  'effort': <gensim.models.keyedvectors.Vocab at 0x7f46f0c81cd0>,
#  'put': <gensim.models.keyedvectors.Vocab at 0x7f46f0c81950>,
#  'chicken': <gensim.models.keyedvectors.Vocab at 0x7f46f0c813d0>,
#  'tasti': <gensim.models.keyedvectors.Vocab at 0x7f46f0c81f90>,
#  'too': <gensim.models.keyedvectors.Vocab at 0x7f46f0c814d0>,
#  'task': <gensim.models.keyedvectors.Vocab at 0x7f46f0c8ab90>,
#  'provid': <gensim.models.keyedvectors.Vocab at 0x7f46f0c8ae10>,
#  'weekli': <gensim.models.keyedvectors.Vocab at 0x7f46f0c8a210>,
#  'play': <gensim.models.keyedvectors.Vocab at 0x7f46f0c8a1d0>,
#  'recogn': <gensim.models.keyedvectors.Vocab at 0x7f46f0c8a450>,
#  'hard': <gensim.models.keyedvectors.Vocab at 0x7f46f0c8ab50>,
#  'thorough': <gensim.models.keyedvectors.Vocab at 0x7f46f0c8a2d0>,
#  'told': <gensim.models.keyedvectors.Vocab at 0x7f46f0c8a3d0>,
#  'knee': <gensim.models.keyedvectors.Vocab at 0x7f46f0c8a690>,
#  'surgeri': <gensim.models.keyedvectors.Vocab at 0x7f46f0c8a650>,
#  'januari': <gensim.models.keyedvectors.Vocab at 0x7f46f0c8ab10>,
#  'ride': <gensim.models.keyedvectors.Vocab at 0x7f46f0c8a150>,
#  'bicycl': <gensim.models.keyedvectors.Vocab at 0x7f46f0c8a110>,
#  'past': <gensim.models.keyedvectors.Vocab at 0x7f46f0c8a810>,
#  'combin': <gensim.models.keyedvectors.Vocab at 0x7f46f0c8a310>,
#  '35': <gensim.models.keyedvectors.Vocab at 0x7f46f0c8a410>,
#  'big': <gensim.models.keyedvectors.Vocab at 0x7f46f0c8a490>,
#  'state': <gensim.models.keyedvectors.Vocab at 0x7f46f0c8ad10>,
#  'polit': <gensim.models.keyedvectors.Vocab at 0x7f46f0c8acd0>,
#  'parti': <gensim.models.keyedvectors.Vocab at 0x7f46f0c8a6d0>,
#  'india': <gensim.models.keyedvectors.Vocab at 0x7f46f0c8a290>,
#  'know': <gensim.models.keyedvectors.Vocab at 0x7f46f0c8a950>,
#  'book': <gensim.models.keyedvectors.Vocab at 0x7f46f0c8ac50>,
#  'girlfriend': <gensim.models.keyedvectors.Vocab at 0x7f46f0c8af10>,
#  'accept': <gensim.models.keyedvectors.Vocab at 0x7f46f0c8ad50>,
#  'publish': <gensim.models.keyedvectors.Vocab at 0x7f46f0c8aa50>,
#  'import': <gensim.models.keyedvectors.Vocab at 0x7f46f0c8a850>,
#  'your': <gensim.models.keyedvectors.Vocab at 0x7f46f0c8a750>,
#  'feedback': <gensim.models.keyedvectors.Vocab at 0x7f46f0c8aa10>,
#  'no': <gensim.models.keyedvectors.Vocab at 0x7f46f0c8af90>,
#  'matter': <gensim.models.keyedvectors.Vocab at 0x7f46f0c8e5d0>,
#  'if': <gensim.models.keyedvectors.Vocab at 0x7f46f0c8ed10>,
#  'ita': <gensim.models.keyedvectors.Vocab at 0x7f46f0c8e290>,
#  'posit': <gensim.models.keyedvectors.Vocab at 0x7f46f0c8e9d0>,
#  'or': <gensim.models.keyedvectors.Vocab at 0x7f46f0c8e110>,
#  'neg': <gensim.models.keyedvectors.Vocab at 0x7f46f0c8eb10>,
#  'you': <gensim.models.keyedvectors.Vocab at 0x7f46f0c8ec90>,
#  'what': <gensim.models.keyedvectors.Vocab at 0x7f46f0c8ef50>,
#  'chang': <gensim.models.keyedvectors.Vocab at 0x7f46f0c8e490>,
#  'repres': <gensim.models.keyedvectors.Vocab at 0x7f46f0c8e910>,
#  'instrument': <gensim.models.keyedvectors.Vocab at 0x7f46f0c8ed90>,
#  'qualiti': <gensim.models.keyedvectors.Vocab at 0x7f46f0c8e3d0>,
#  'onli': <gensim.models.keyedvectors.Vocab at 0x7f46f0c8e8d0>,
#  'best': <gensim.models.keyedvectors.Vocab at 0x7f46f0c8ea10>,
#  'intent': <gensim.models.keyedvectors.Vocab at 0x7f46f0c8e990>,
#  'transform': <gensim.models.keyedvectors.Vocab at 0x7f46f0c8e7d0>,
#  'product': <gensim.models.keyedvectors.Vocab at 0x7f46f0c8e850>,
#  'cheer': <gensim.models.keyedvectors.Vocab at 0x7f46f0c8ef10>,
#  'motiv': <gensim.models.keyedvectors.Vocab at 0x7f46f0c8e190>,
#  'train': <gensim.models.keyedvectors.Vocab at 0x7f46f0c8e150>,
#  'program': <gensim.models.keyedvectors.Vocab at 0x7f46f0c8ea90>,
#  'therebi': <gensim.models.keyedvectors.Vocab at 0x7f46f0c8ecd0>,
#  'better': <gensim.models.keyedvectors.Vocab at 0x7f46f0c8ee50>,
#  'focus': <gensim.models.keyedvectors.Vocab at 0x7f46f0c8e610>,
#  'improv': <gensim.models.keyedvectors.Vocab at 0x7f46f0c8e250>,
#  'skill': <gensim.models.keyedvectors.Vocab at 0x7f46f0c8e050>,
#  "'ll": <gensim.models.keyedvectors.Vocab at 0x7f46f0c8e510>,
#  'though': <gensim.models.keyedvectors.Vocab at 0x7f46efddae50>,
#  'woke': <gensim.models.keyedvectors.Vocab at 0x7f46efdda8d0>,
#  'late': <gensim.models.keyedvectors.Vocab at 0x7f46efddac90>,
#  'find': <gensim.models.keyedvectors.Vocab at 0x7f46efdda2d0>,
#  'box': <gensim.models.keyedvectors.Vocab at 0x7f46efdda190>,
#  'magic': <gensim.models.keyedvectors.Vocab at 0x7f46efdda110>,
#  'gather': <gensim.models.keyedvectors.Vocab at 0x7f46efdda9d0>,
#  'cheap': <gensim.models.keyedvectors.Vocab at 0x7f46efdda690>,
#  'garag': <gensim.models.keyedvectors.Vocab at 0x7f46efddad50>,
#  'enough': <gensim.models.keyedvectors.Vocab at 0x7f46efdda7d0>,
#  'special': <gensim.models.keyedvectors.Vocab at 0x7f46efddac10>,
#  'edit': <gensim.models.keyedvectors.Vocab at 0x7f46efddaa50>,
#  'want': <gensim.models.keyedvectors.Vocab at 0x7f46efdda990>,
#  'awhil': <gensim.models.keyedvectors.Vocab at 0x7f46efdda050>,
#  'technic': <gensim.models.keyedvectors.Vocab at 0x7f46efddad90>,
#  'expert': <gensim.models.keyedvectors.Vocab at 0x7f46efdda250>,
#  'handl': <gensim.models.keyedvectors.Vocab at 0x7f46efdda750>,
#  'such': <gensim.models.keyedvectors.Vocab at 0x7f46efddae10>,
#  'decid': <gensim.models.keyedvectors.Vocab at 0x7f46efdda6d0>,
#  'show': <gensim.models.keyedvectors.Vocab at 0x7f46efdda590>,
#  'solv': <gensim.models.keyedvectors.Vocab at 0x7f46efdda290>,
#  'it.i': <gensim.models.keyedvectors.Vocab at 0x7f46efdda810>,
#  'imag': <gensim.models.keyedvectors.Vocab at 0x7f46efdda4d0>,
#  'taken': <gensim.models.keyedvectors.Vocab at 0x7f46efdda650>,
#  'normal': <gensim.models.keyedvectors.Vocab at 0x7f46efddacd0>,
#  'level': <gensim.models.keyedvectors.Vocab at 0x7f46efddae90>,
#  'post': <gensim.models.keyedvectors.Vocab at 0x7f46efdd58d0>,
#  'attend': <gensim.models.keyedvectors.Vocab at 0x7f46efdd5c50>,
#  'discuss': <gensim.models.keyedvectors.Vocab at 0x7f46efdd54d0>,
#  'could': <gensim.models.keyedvectors.Vocab at 0x7f46efdd5bd0>,
#  'gain': <gensim.models.keyedvectors.Vocab at 0x7f46efdd5710>,
#  'their': <gensim.models.keyedvectors.Vocab at 0x7f46efdd5110>,
#  'trust': <gensim.models.keyedvectors.Vocab at 0x7f46efdd5f10>,
#  'claim': <gensim.models.keyedvectors.Vocab at 0x7f46efdd50d0>,
#  'back': <gensim.models.keyedvectors.Vocab at 0x7f46efdd5750>,
#  '95': <gensim.models.keyedvectors.Vocab at 0x7f46efdd5610>,
#  '%': <gensim.models.keyedvectors.Vocab at 0x7f46efdd5410>,
#  'insur': <gensim.models.keyedvectors.Vocab at 0x7f46efdd5e50>,
#  'lotteri': <gensim.models.keyedvectors.Vocab at 0x7f46efdd5310>,
#  'societi': <gensim.models.keyedvectors.Vocab at 0x7f46efdd5910>,
#  'donat': <gensim.models.keyedvectors.Vocab at 0x7f46efdd57d0>,
#  'whole': <gensim.models.keyedvectors.Vocab at 0x7f46efdd5d50>,
#  'amount': <gensim.models.keyedvectors.Vocab at 0x7f46efdd5d90>,
#  'kid': <gensim.models.keyedvectors.Vocab at 0x7f46efdd5250>,
#  'fund': <gensim.models.keyedvectors.Vocab at 0x7f46efdd5ad0>,
#  'volleybal': <gensim.models.keyedvectors.Vocab at 0x7f46efdd5350>,
#  'tournament': <gensim.models.keyedvectors.Vocab at 0x7f46efdd5190>,
#  'qualifi': <gensim.models.keyedvectors.Vocab at 0x7f46efdd5950>,
#  'match': <gensim.models.keyedvectors.Vocab at 0x7f46efdd53d0>,
#  'read': <gensim.models.keyedvectors.Vocab at 0x7f46efdd5c10>,
#  'paper': <gensim.models.keyedvectors.Vocab at 0x7f46efdd5890>,
#  'photo': <gensim.models.keyedvectors.Vocab at 0x7f46efdd5790>,
#  'newspap': <gensim.models.keyedvectors.Vocab at 0x7f46efdd5a50>,
#  'column': <gensim.models.keyedvectors.Vocab at 0x7f46efdd5a90>,
#  'given': <gensim.models.keyedvectors.Vocab at 0x7f46efdd5290>,
#  'staff': <gensim.models.keyedvectors.Vocab at 0x7f46efdd5850>,
#  'bonu': <gensim.models.keyedvectors.Vocab at 0x7f46efdd5650>,
#  'applianc': <gensim.models.keyedvectors.Vocab at 0x7f46efd734d0>,
#  'kitchen': <gensim.models.keyedvectors.Vocab at 0x7f46efd73bd0>,
#  'met': <gensim.models.keyedvectors.Vocab at 0x7f46efd730d0>,
#  'target': <gensim.models.keyedvectors.Vocab at 0x7f46efd73590>,
#  'usual': <gensim.models.keyedvectors.Vocab at 0x7f46efd73790>,
#  'system': <gensim.models.keyedvectors.Vocab at 0x7f46efd73050>,
#  'cell': <gensim.models.keyedvectors.Vocab at 0x7f46efd731d0>,
#  'latest': <gensim.models.keyedvectors.Vocab at 0x7f46efd73090>,
#  'featur': <gensim.models.keyedvectors.Vocab at 0x7f46efd73650>,
#  'specif': <gensim.models.keyedvectors.Vocab at 0x7f46efd738d0>,
#  'discount': <gensim.models.keyedvectors.Vocab at 0x7f46efd735d0>,
#  'internet': <gensim.models.keyedvectors.Vocab at 0x7f46efd73a50>,
#  'pack': <gensim.models.keyedvectors.Vocab at 0x7f46efd73550>,
#  'brand': <gensim.models.keyedvectors.Vocab at 0x7f46efd73310>,
#  'motorcycl': <gensim.models.keyedvectors.Vocab at 0x7f46efd73850>,
#  'myself': <gensim.models.keyedvectors.Vocab at 0x7f46efd73e50>,
#  'ring': <gensim.models.keyedvectors.Vocab at 0x7f46efd73b50>,
#  'own': <gensim.models.keyedvectors.Vocab at 0x7f46efd73f90>,
#  'earn': <gensim.models.keyedvectors.Vocab at 0x7f46efd73a10>,
#  'graduat': <gensim.models.keyedvectors.Vocab at 0x7f46efd73890>,
#  'make': <gensim.models.keyedvectors.Vocab at 0x7f46efd73dd0>,
#  'accomplish': <gensim.models.keyedvectors.Vocab at 0x7f46efd73490>,
#  'currenc': <gensim.models.keyedvectors.Vocab at 0x7f46efd73950>,
#  'market': <gensim.models.keyedvectors.Vocab at 0x7f46efd733d0>,
#  'method': <gensim.models.keyedvectors.Vocab at 0x7f46efd73f10>,
#  '50': <gensim.models.keyedvectors.Vocab at 0x7f46efd73cd0>,
#  'cricket': <gensim.models.keyedvectors.Vocab at 0x7f46efd73e90>,
#  'old': <gensim.models.keyedvectors.Vocab at 0x7f46efd73b10>,
#  'homework': <gensim.models.keyedvectors.Vocab at 0x7f46efd73d50>,
#  'offer': <gensim.models.keyedvectors.Vocab at 0x7f46efd89c10>,
#  'recharg': <gensim.models.keyedvectors.Vocab at 0x7f46efd89e90>,
#  'remodel': <gensim.models.keyedvectors.Vocab at 0x7f46efd89310>,
#  'garden': <gensim.models.keyedvectors.Vocab at 0x7f46efd891d0>,
#  'idea': <gensim.models.keyedvectors.Vocab at 0x7f46efd89150>,
#  'email': <gensim.models.keyedvectors.Vocab at 0x7f46efd89d10>,
#  'say': <gensim.models.keyedvectors.Vocab at 0x7f46efd89790>,
#  'research': <gensim.models.keyedvectors.Vocab at 0x7f46efd89a10>,
#  'diabet': <gensim.models.keyedvectors.Vocab at 0x7f46efd896d0>,
#  'approv': <gensim.models.keyedvectors.Vocab at 0x7f46efd899d0>,
#  '24': <gensim.models.keyedvectors.Vocab at 0x7f46efd89dd0>,
#  'hour': <gensim.models.keyedvectors.Vocab at 0x7f46efd89650>,
#  'kept': <gensim.models.keyedvectors.Vocab at 0x7f46efd89990>,
#  'fashion': <gensim.models.keyedvectors.Vocab at 0x7f46efd89b10>,
#  'design': <gensim.models.keyedvectors.Vocab at 0x7f46efd89210>,
#  'exhibit': <gensim.models.keyedvectors.Vocab at 0x7f46efd898d0>,
#  'n': <gensim.models.keyedvectors.Vocab at 0x7f46efd89890>,
#  'dress': <gensim.models.keyedvectors.Vocab at 0x7f46efd89b90>,
#  'nice': <gensim.models.keyedvectors.Vocab at 0x7f46efd89390>,
#  'progress': <gensim.models.keyedvectors.Vocab at 0x7f46efd89190>,
#  'rusti': <gensim.models.keyedvectors.Vocab at 0x7f46efd89810>,
#  'restor': <gensim.models.keyedvectors.Vocab at 0x7f46efd89f50>,
#  'paint': <gensim.models.keyedvectors.Vocab at 0x7f46efd89510>,
#  'figur': <gensim.models.keyedvectors.Vocab at 0x7f46efd89750>,
#  'how': <gensim.models.keyedvectors.Vocab at 0x7f46efd89110>,
#  'mount': <gensim.models.keyedvectors.Vocab at 0x7f46efd894d0>,
#  'tool': <gensim.models.keyedvectors.Vocab at 0x7f46efd89610>,
#  'pick': <gensim.models.keyedvectors.Vocab at 0x7f46efd89350>,
#  'vibrat': <gensim.models.keyedvectors.Vocab at 0x7f46efd89710>,
#  'parcel': <gensim.models.keyedvectors.Vocab at 0x7f46efd89450>,
#  'germani': <gensim.models.keyedvectors.Vocab at 0x7f46efd89a90>,
#  'gon': <gensim.models.keyedvectors.Vocab at 0x7f46efd93a50>,
#  'na': <gensim.models.keyedvectors.Vocab at 0x7f46efd93950>,
#  'grow': <gensim.models.keyedvectors.Vocab at 0x7f46efd93dd0>,
#  'steadili': <gensim.models.keyedvectors.Vocab at 0x7f46efd93e10>,
#  'kettl': <gensim.models.keyedvectors.Vocab at 0x7f46efd931d0>,
#  'inform': <gensim.models.keyedvectors.Vocab at 0x7f46efd93c90>,
#  'pay': <gensim.models.keyedvectors.Vocab at 0x7f46efd938d0>,
#  'compar': <gensim.models.keyedvectors.Vocab at 0x7f46efd93e90>,
#  '1.5': <gensim.models.keyedvectors.Vocab at 0x7f46efd93410>,
#  'errand': <gensim.models.keyedvectors.Vocab at 0x7f46efd93650>,
#  'wake': <gensim.models.keyedvectors.Vocab at 0x7f46efd93d10>,
#  'dinner': <gensim.models.keyedvectors.Vocab at 0x7f46efd93ad0>,
#  'colleg': <gensim.models.keyedvectors.Vocab at 0x7f46efd932d0>,
#  'class': <gensim.models.keyedvectors.Vocab at 0x7f46efd93290>,
#  'set': <gensim.models.keyedvectors.Vocab at 0x7f46efd93590>,
#  'vacat': <gensim.models.keyedvectors.Vocab at 0x7f46efd93f50>,
#  'summer': <gensim.models.keyedvectors.Vocab at 0x7f46efd93150>,
#  'weightlift': <gensim.models.keyedvectors.Vocab at 0x7f46efd93550>,
#  'photographi': <gensim.models.keyedvectors.Vocab at 0x7f46efd93310>,
#  'compos': <gensim.models.keyedvectors.Vocab at 0x7f46efd93210>,
#  'song': <gensim.models.keyedvectors.Vocab at 0x7f46efd93490>,
#  'fill': <gensim.models.keyedvectors.Vocab at 0x7f46efd93a90>,
#  'bike': <gensim.models.keyedvectors.Vocab at 0x7f46efd93850>,
#  'fuel': <gensim.models.keyedvectors.Vocab at 0x7f46efd93450>,
#  'tank': <gensim.models.keyedvectors.Vocab at 0x7f46efd93810>,
#  'outsid': <gensim.models.keyedvectors.Vocab at 0x7f46efd93cd0>,
#  'fli': <gensim.models.keyedvectors.Vocab at 0x7f46efd93c10>,
#  'quadcopt': <gensim.models.keyedvectors.Vocab at 0x7f46efd93250>,
#  'equip': <gensim.models.keyedvectors.Vocab at 0x7f46efd93f90>,
#  'led': <gensim.models.keyedvectors.Vocab at 0x7f46efd93b90>,
#  'easi': <gensim.models.keyedvectors.Vocab at 0x7f46efd939d0>,
#  'somewhat': <gensim.models.keyedvectors.Vocab at 0x7f46efda7110>,
#  'difficult': <gensim.models.keyedvectors.Vocab at 0x7f46efda7b50>,
#  'other': <gensim.models.keyedvectors.Vocab at 0x7f46efda7150>,
#  'over': <gensim.models.keyedvectors.Vocab at 0x7f46efda7f50>,
#  'minut': <gensim.models.keyedvectors.Vocab at 0x7f46efda7ed0>,
#  'neighbor': <gensim.models.keyedvectors.Vocab at 0x7f46efda7ad0>,
#  'permiss': <gensim.models.keyedvectors.Vocab at 0x7f46efda7bd0>,
#  'total': <gensim.models.keyedvectors.Vocab at 0x7f46efda7450>,
#  'challeng': <gensim.models.keyedvectors.Vocab at 0x7f46efda7390>,
#  'super': <gensim.models.keyedvectors.Vocab at 0x7f46efda7e10>,
#  'fun': <gensim.models.keyedvectors.Vocab at 0x7f46efda7710>,
#  'appli': <gensim.models.keyedvectors.Vocab at 0x7f46efda7d10>,
#  'didnt': <gensim.models.keyedvectors.Vocab at 0x7f46efda7b10>,
#  'ani': <gensim.models.keyedvectors.Vocab at 0x7f46efda7d50>,
#  'messag': <gensim.models.keyedvectors.Vocab at 0x7f46efda72d0>,
#  'univers': <gensim.models.keyedvectors.Vocab at 0x7f46efda79d0>,
#  'postman': <gensim.models.keyedvectors.Vocab at 0x7f46efda71d0>,
#  'hand': <gensim.models.keyedvectors.Vocab at 0x7f46efda7190>,
#  'cover': <gensim.models.keyedvectors.Vocab at 0x7f46efda7fd0>,
#  'grant': <gensim.models.keyedvectors.Vocab at 0x7f46efda76d0>,
#  'prepar': <gensim.models.keyedvectors.Vocab at 0x7f46efda7b90>,
#  'iam': <gensim.models.keyedvectors.Vocab at 0x7f46efda7210>,
#  'higher': <gensim.models.keyedvectors.Vocab at 0x7f46efda7610>,
#  'grade': <gensim.models.keyedvectors.Vocab at 0x7f46efda7690>,
#  'test': <gensim.models.keyedvectors.Vocab at 0x7f46efda7810>,
#  'brew': <gensim.models.keyedvectors.Vocab at 0x7f46efd99250>,
#  'tea': <gensim.models.keyedvectors.Vocab at 0x7f46efd99190>,
#  'profound': <gensim.models.keyedvectors.Vocab at 0x7f46efd99110>,
#  'compliment': <gensim.models.keyedvectors.Vocab at 0x7f46efd99b90>,
#  'instructor': <gensim.models.keyedvectors.Vocab at 0x7f46efd99450>,
#  'mine': <gensim.models.keyedvectors.Vocab at 0x7f46efd99650>,
#  'imposs': <gensim.models.keyedvectors.Vocab at 0x7f46efd99d50>,
#  'both': <gensim.models.keyedvectors.Vocab at 0x7f46efd99810>,
#  'princip': <gensim.models.keyedvectors.Vocab at 0x7f46efd99090>,
#  'vice': <gensim.models.keyedvectors.Vocab at 0x7f46efd997d0>,
#  'were': <gensim.models.keyedvectors.Vocab at 0x7f46efd994d0>,
#  'sub': <gensim.models.keyedvectors.Vocab at 0x7f46efd99410>,
#  'teacher': <gensim.models.keyedvectors.Vocab at 0x7f46efd99990>,
#  'few': <gensim.models.keyedvectors.Vocab at 0x7f46efd99290>,
#  'ago': <gensim.models.keyedvectors.Vocab at 0x7f46efd99710>,
#  'alreadi': <gensim.models.keyedvectors.Vocab at 0x7f46efd99890>,
#  'becaus': <gensim.models.keyedvectors.Vocab at 0x7f46efd992d0>,
#  'issu': <gensim.models.keyedvectors.Vocab at 0x7f46efd99490>,
#  'master': <gensim.models.keyedvectors.Vocab at 0x7f46efd995d0>,
#  'crispi': <gensim.models.keyedvectors.Vocab at 0x7f46efd99390>,
#  'tofu': <gensim.models.keyedvectors.Vocab at 0x7f46efd99150>,
#  'delici': <gensim.models.keyedvectors.Vocab at 0x7f46efd996d0>,
#  'soup': <gensim.models.keyedvectors.Vocab at 0x7f46efd99ad0>,
#  'dumpl': <gensim.models.keyedvectors.Vocab at 0x7f46efd99550>,
#  'dish': <gensim.models.keyedvectors.Vocab at 0x7f46efd99790>,
#  'hair': <gensim.models.keyedvectors.Vocab at 0x7f46efd99a50>,
#  'soft': <gensim.models.keyedvectors.Vocab at 0x7f46efd99f50>,
#  'instead': <gensim.models.keyedvectors.Vocab at 0x7f46efd99b10>,
#  'tradit': <gensim.models.keyedvectors.Vocab at 0x7f46efd99e90>,
#  'metal': <gensim.models.keyedvectors.Vocab at 0x7f46efd99e10>,
#  'beef': <gensim.models.keyedvectors.Vocab at 0x7f46efd99f90>,
#  'did': <gensim.models.keyedvectors.Vocab at 0x7f46efd22290>,
#  'end': <gensim.models.keyedvectors.Vocab at 0x7f46efd22790>,
#  'comput': <gensim.models.keyedvectors.Vocab at 0x7f46efd221d0>,
#  'thing': <gensim.models.keyedvectors.Vocab at 0x7f46efd22250>,
#  'prais': <gensim.models.keyedvectors.Vocab at 0x7f46efd22ad0>,
#  'rate': <gensim.models.keyedvectors.Vocab at 0x7f46efd22310>,
#  'wireless': <gensim.models.keyedvectors.Vocab at 0x7f46efd22a10>,
#  'headphon': <gensim.models.keyedvectors.Vocab at 0x7f46efd22fd0>,
#  'iphon': <gensim.models.keyedvectors.Vocab at 0x7f46efd22dd0>,
#  '7': <gensim.models.keyedvectors.Vocab at 0x7f46efd22690>,
#  'plu': <gensim.models.keyedvectors.Vocab at 0x7f46efd22890>,
#  'night': <gensim.models.keyedvectors.Vocab at 0x7f46efd22210>,
#  'medal': <gensim.models.keyedvectors.Vocab at 0x7f46efd22410>,
#  'footbal': <gensim.models.keyedvectors.Vocab at 0x7f46efd22550>,
#  'between': <gensim.models.keyedvectors.Vocab at 0x7f46efd22a50>,
#  'vs': <gensim.models.keyedvectors.Vocab at 0x7f46efd22750>,
#  'point': <gensim.models.keyedvectors.Vocab at 0x7f46efd22bd0>,
#  'join': <gensim.models.keyedvectors.Vocab at 0x7f46efd22490>,
#  'dota': <gensim.models.keyedvectors.Vocab at 0x7f46efd22c50>,
#  '``': <gensim.models.keyedvectors.Vocab at 0x7f46efd220d0>,
#  'intern': <gensim.models.keyedvectors.Vocab at 0x7f46efd223d0>,
#  "''": <gensim.models.keyedvectors.Vocab at 0x7f46efd22d10>,
#  'valv': <gensim.models.keyedvectors.Vocab at 0x7f46efd22590>,
#  'king': <gensim.models.keyedvectors.Vocab at 0x7f46efd222d0>,
#  'beer': <gensim.models.keyedvectors.Vocab at 0x7f46efd22610>,
#  '2000': <gensim.models.keyedvectors.Vocab at 0x7f46efd227d0>,
#  'dac': <gensim.models.keyedvectors.Vocab at 0x7f46efd22850>,
#  'championship': <gensim.models.keyedvectors.Vocab at 0x7f46efd226d0>,
#  'defeat': <gensim.models.keyedvectors.Vocab at 0x7f46efd22cd0>,
#  'warrior': <gensim.models.keyedvectors.Vocab at 0x7f46efd229d0>,
#  'nba': <gensim.models.keyedvectors.Vocab at 0x7f46efd22e10>,
#  'tittl': <gensim.models.keyedvectors.Vocab at 0x7f46efd7f190>,
#  'reput': <gensim.models.keyedvectors.Vocab at 0x7f46efd7f4d0>,
#  'competit': <gensim.models.keyedvectors.Vocab at 0x7f46efd7f310>,
#  '5': <gensim.models.keyedvectors.Vocab at 0x7f46efd7f550>,
#  'quiz': <gensim.models.keyedvectors.Vocab at 0x7f46efd7fe10>,
#  'televis': <gensim.models.keyedvectors.Vocab at 0x7f46efd7fb50>,
#  'senior': <gensim.models.keyedvectors.Vocab at 0x7f46efd7f850>,
#  'groceri': <gensim.models.keyedvectors.Vocab at 0x7f46efd7fad0>,
#  'shop': <gensim.models.keyedvectors.Vocab at 0x7f46efd7fc10>,
#  'dollar': <gensim.models.keyedvectors.Vocab at 0x7f46efd7fe50>,
#  'ground': <gensim.models.keyedvectors.Vocab at 0x7f46efd7f290>,
#  'insid': <gensim.models.keyedvectors.Vocab at 0x7f46efd7f150>,
#  'breakfast': <gensim.models.keyedvectors.Vocab at 0x7f46efd7f3d0>,
#  'build': <gensim.models.keyedvectors.Vocab at 0x7f46efd7f110>,
#  'stop': <gensim.models.keyedvectors.Vocab at 0x7f46efd7f990>,
#  'smoke': <gensim.models.keyedvectors.Vocab at 0x7f46efd7fa50>,
#  'appl': <gensim.models.keyedvectors.Vocab at 0x7f46efd7ffd0>,
#  'coupl': <gensim.models.keyedvectors.Vocab at 0x7f46efd7fc50>,
# ...
#  'stuff': <gensim.models.keyedvectors.Vocab at 0x7f46efd7f590>,
#  'tip': <gensim.models.keyedvectors.Vocab at 0x7f46efd7f9d0>,
#  'present': <gensim.models.keyedvectors.Vocab at 0x7f46efd7f7d0>,
#  'movi': <gensim.models.keyedvectors.Vocab at 0x7f46efd7fd50>,
#  'gift': <gensim.models.keyedvectors.Vocab at 0x7f46efd7f390>,
#  'walmart': <gensim.models.keyedvectors.Vocab at 0x7f46efd7fd10>,
#  'also': <gensim.models.keyedvectors.Vocab at 0x7f46efd7fa90>,
#  'highli': <gensim.models.keyedvectors.Vocab at 0x7f46efd7f690>,
#  'afford': <gensim.models.keyedvectors.Vocab at 0x7f46efd7f750>,
#  'recip': <gensim.models.keyedvectors.Vocab at 0x7f46efd7f5d0>,
#  'tax': <gensim.models.keyedvectors.Vocab at 0x7f46efdb06d0>,
#  'paperwork': <gensim.models.keyedvectors.Vocab at 0x7f46efdb0f90>,
#  'line': <gensim.models.keyedvectors.Vocab at 0x7f46efdb0950>,
#  '5000': <gensim.models.keyedvectors.Vocab at 0x7f46efdb0110>,
#  'break': <gensim.models.keyedvectors.Vocab at 0x7f46efdb0a10>,
#  'fast': <gensim.models.keyedvectors.Vocab at 0x7f46efdb0650>,
#  'financ': <gensim.models.keyedvectors.Vocab at 0x7f46efdb0ad0>,
#  'bill': <gensim.models.keyedvectors.Vocab at 0x7f46efdb0090>,
#  'chip': <gensim.models.keyedvectors.Vocab at 0x7f46efdb02d0>,
#  'juli': <gensim.models.keyedvectors.Vocab at 0x7f46efdb0610>,
#  'bring': <gensim.models.keyedvectors.Vocab at 0x7f46efdb0e90>,
#  'qualif': <gensim.models.keyedvectors.Vocab at 0x7f46efdb0d90>,
#  'mturk': <gensim.models.keyedvectors.Vocab at 0x7f46efdb0f50>,
#  '42': <gensim.models.keyedvectors.Vocab at 0x7f46efdb0e10>,
#  '30': <gensim.models.keyedvectors.Vocab at 0x7f46efdb00d0>,
#  'daughter': <gensim.models.keyedvectors.Vocab at 0x7f46efdb0190>,
#  'learnt': <gensim.models.keyedvectors.Vocab at 0x7f46efdb0750>,
#  'mother': <gensim.models.keyedvectors.Vocab at 0x7f46efdb0350>,
#  'drive': <gensim.models.keyedvectors.Vocab at 0x7f46efdb0550>,
#  'age': <gensim.models.keyedvectors.Vocab at 0x7f46efdb05d0>,
#  "'m": <gensim.models.keyedvectors.Vocab at 0x7f46efdb0a50>,
#  'form': <gensim.models.keyedvectors.Vocab at 0x7f46efdb0b50>,
#  'teammat': <gensim.models.keyedvectors.Vocab at 0x7f46efdb04d0>,
#  'daston': <gensim.models.keyedvectors.Vocab at 0x7f46efdb0c50>,
#  'power': <gensim.models.keyedvectors.Vocab at 0x7f46efdb0850>,
#  'milag': <gensim.models.keyedvectors.Vocab at 0x7f46efdb0f10>,
#  'regain': <gensim.models.keyedvectors.Vocab at 0x7f46efdb0dd0>,
#  'strength': <gensim.models.keyedvectors.Vocab at 0x7f46efd53950>,
#  'gym': <gensim.models.keyedvectors.Vocab at 0x7f46efd53790>,
#  'reliev': <gensim.models.keyedvectors.Vocab at 0x7f46efd53ad0>,
#  'duti': <gensim.models.keyedvectors.Vocab at 0x7f46efd53b10>,
#  'longer': <gensim.models.keyedvectors.Vocab at 0x7f46efd53a50>,
#  'exceed': <gensim.models.keyedvectors.Vocab at 0x7f46efd538d0>,
#  'loss': <gensim.models.keyedvectors.Vocab at 0x7f46efd53a10>,
#  'goal': <gensim.models.keyedvectors.Vocab at 0x7f46efd53450>,
#  'toward': <gensim.models.keyedvectors.Vocab at 0x7f46efd53990>,
#  'februari': <gensim.models.keyedvectors.Vocab at 0x7f46efd53410>,
#  'pork': <gensim.models.keyedvectors.Vocab at 0x7f46efd53210>,
#  'worri': <gensim.models.keyedvectors.Vocab at 0x7f46efd535d0>,
#  'taught': <gensim.models.keyedvectors.Vocab at 0x7f46efd53d90>,
#  'step': <gensim.models.keyedvectors.Vocab at 0x7f46efd53c10>,
#  'quicker': <gensim.models.keyedvectors.Vocab at 0x7f46efd53f10>,
#  'she': <gensim.models.keyedvectors.Vocab at 0x7f46efd53f90>,
#  'washer': <gensim.models.keyedvectors.Vocab at 0x7f46efd53ed0>,
#  'dryer': <gensim.models.keyedvectors.Vocab at 0x7f46efd53c90>,
#  'favorit': <gensim.models.keyedvectors.Vocab at 0x7f46efd53690>,
#  'stereo': <gensim.models.keyedvectors.Vocab at 0x7f46efd530d0>,
#  'side': <gensim.models.keyedvectors.Vocab at 0x7f46efd53350>,
#  'bough': <gensim.models.keyedvectors.Vocab at 0x7f46efd536d0>,
#  'said': <gensim.models.keyedvectors.Vocab at 0x7f46efd532d0>,
#  'excel': <gensim.models.keyedvectors.Vocab at 0x7f46efd53590>,
#  'buy': <gensim.models.keyedvectors.Vocab at 0x7f46efd537d0>,
#  'soni': <gensim.models.keyedvectors.Vocab at 0x7f46efd533d0>,
#  'store': <gensim.models.keyedvectors.Vocab at 0x7f46efd53250>,
#  'review': <gensim.models.keyedvectors.Vocab at 0x7f46efd53490>,
#  'flower': <gensim.models.keyedvectors.Vocab at 0x7f46efd53150>,
#  'piec': <gensim.models.keyedvectors.Vocab at 0x7f46efd53050>,
#  'candi': <gensim.models.keyedvectors.Vocab at 0x7f46efd474d0>,
#  '75': <gensim.models.keyedvectors.Vocab at 0x7f46efd47f50>,
#  'close': <gensim.models.keyedvectors.Vocab at 0x7f46efd47210>,
#  'prep': <gensim.models.keyedvectors.Vocab at 0x7f46efd473d0>,
#  'oatmeal': <gensim.models.keyedvectors.Vocab at 0x7f46efd47350>,
#  'plenti': <gensim.models.keyedvectors.Vocab at 0x7f46efd47410>,
#  'readi': <gensim.models.keyedvectors.Vocab at 0x7f46efd47d90>,
#  'sever': <gensim.models.keyedvectors.Vocab at 0x7f46efd47850>,
#  'allow': <gensim.models.keyedvectors.Vocab at 0x7f46efd47ed0>,
#  'studi': <gensim.models.keyedvectors.Vocab at 0x7f46efd478d0>,
#  'upcom': <gensim.models.keyedvectors.Vocab at 0x7f46efd47b50>,
#  'sort': <gensim.models.keyedvectors.Vocab at 0x7f46efd477d0>,
#  'document': <gensim.models.keyedvectors.Vocab at 0x7f46efd47e90>,
#  'file': <gensim.models.keyedvectors.Vocab at 0x7f46efd47ad0>,
#  'dirti': <gensim.models.keyedvectors.Vocab at 0x7f46efd47110>,
#  'rug': <gensim.models.keyedvectors.Vocab at 0x7f46efd47c50>,
#  'edg': <gensim.models.keyedvectors.Vocab at 0x7f46efd47e10>,
#  'cut': <gensim.models.keyedvectors.Vocab at 0x7f46efd47cd0>,
#  'grass': <gensim.models.keyedvectors.Vocab at 0x7f46efd47b90>,
#  'grind': <gensim.models.keyedvectors.Vocab at 0x7f46efd47250>,
#  'coffe': <gensim.models.keyedvectors.Vocab at 0x7f46efd47290>,
#  'bean': <gensim.models.keyedvectors.Vocab at 0x7f46efd479d0>,
#  'tast': <gensim.models.keyedvectors.Vocab at 0x7f46efd47b10>,
#  'mental': <gensim.models.keyedvectors.Vocab at 0x7f46efd471d0>,
#  'sleep': <gensim.models.keyedvectors.Vocab at 0x7f46efd47490>,
#  'cloth': <gensim.models.keyedvectors.Vocab at 0x7f46efd47650>,
#  'pad': <gensim.models.keyedvectors.Vocab at 0x7f46efd47610>,
#  'dispos': <gensim.models.keyedvectors.Vocab at 0x7f46efd47710>,
#  'cotton': <gensim.models.keyedvectors.Vocab at 0x7f46efd470d0>,
#  'monthli': <gensim.models.keyedvectors.Vocab at 0x7f46efd47190>,
#  'wast': <gensim.models.keyedvectors.Vocab at 0x7f46efd30050>,
#  'semest': <gensim.models.keyedvectors.Vocab at 0x7f46efd30cd0>,
#  'school': <gensim.models.keyedvectors.Vocab at 0x7f46efd30c50>,
#  'volunt': <gensim.models.keyedvectors.Vocab at 0x7f46efd303d0>,
#  'librari': <gensim.models.keyedvectors.Vocab at 0x7f46efd301d0>,
#  'everyon': <gensim.models.keyedvectors.Vocab at 0x7f46efd30950>,
#  'who': <gensim.models.keyedvectors.Vocab at 0x7f46efd30290>,
#  'impress': <gensim.models.keyedvectors.Vocab at 0x7f46efd30990>,
#  'invit': <gensim.models.keyedvectors.Vocab at 0x7f46efd30750>,
#  'survey': <gensim.models.keyedvectors.Vocab at 0x7f46efd30ad0>,
#  '100': <gensim.models.keyedvectors.Vocab at 0x7f46efd30910>,
#  'bake': <gensim.models.keyedvectors.Vocab at 0x7f46efd30e10>,
#  'cooki': <gensim.models.keyedvectors.Vocab at 0x7f46efd30d50>,
#  'someon': <gensim.models.keyedvectors.Vocab at 0x7f46efd30d10>,
#  "'d": <gensim.models.keyedvectors.Vocab at 0x7f46efd30dd0>,
#  'ever': <gensim.models.keyedvectors.Vocab at 0x7f46efd30590>,
#  'mechan': <gensim.models.keyedvectors.Vocab at 0x7f46efd30410>,
#  'turk': <gensim.models.keyedvectors.Vocab at 0x7f46efd305d0>,
#  'arrang': <gensim.models.keyedvectors.Vocab at 0x7f46efd30a90>,
#  'kansa': <gensim.models.keyedvectors.Vocab at 0x7f46efd30710>,
#  'june': <gensim.models.keyedvectors.Vocab at 0x7f46efd30f50>,
#  'weekend': <gensim.models.keyedvectors.Vocab at 0x7f46efd30ed0>,
#  'independ': <gensim.models.keyedvectors.Vocab at 0x7f46efd30210>,
#  'becom': <gensim.models.keyedvectors.Vocab at 0x7f46efd304d0>,
#  'joy': <gensim.models.keyedvectors.Vocab at 0x7f46efd30550>,
#  'color': <gensim.models.keyedvectors.Vocab at 0x7f46efd30350>,
#  'straighten': <gensim.models.keyedvectors.Vocab at 0x7f46efd30690>,
#  'primari': <gensim.models.keyedvectors.Vocab at 0x7f46efd30510>,
#  'hail': <gensim.models.keyedvectors.Vocab at 0x7f46efd30150>,
#  'damag': <gensim.models.keyedvectors.Vocab at 0x7f46efd30b50>,
#  'storm': <gensim.models.keyedvectors.Vocab at 0x7f46efd30e90>,
#  'result': <gensim.models.keyedvectors.Vocab at 0x7f46efd3c0d0>,
#  'diet': <gensim.models.keyedvectors.Vocab at 0x7f46efd3c310>,
#  'solid': <gensim.models.keyedvectors.Vocab at 0x7f46efd3c050>,
#  'balanc': <gensim.models.keyedvectors.Vocab at 0x7f46efd3c090>,
#  'profession': <gensim.models.keyedvectors.Vocab at 0x7f46efd3c610>,
#  'ice': <gensim.models.keyedvectors.Vocab at 0x7f46efd3c150>,
#  'doe': <gensim.models.keyedvectors.Vocab at 0x7f46efd3cb10>,
#  'continu': <gensim.models.keyedvectors.Vocab at 0x7f46efd3c590>,
#  'plant': <gensim.models.keyedvectors.Vocab at 0x7f46efd3c410>,
#  'cool': <gensim.models.keyedvectors.Vocab at 0x7f46efd3c890>,
#  'weather': <gensim.models.keyedvectors.Vocab at 0x7f46efd3cfd0>,
#  'lettuc': <gensim.models.keyedvectors.Vocab at 0x7f46efd3c810>,
#  'cabbag': <gensim.models.keyedvectors.Vocab at 0x7f46efd3c690>,
#  'golf': <gensim.models.keyedvectors.Vocab at 0x7f46efd3c6d0>,
#  'bag': <gensim.models.keyedvectors.Vocab at 0x7f46efd3c5d0>,
#  'love': <gensim.models.keyedvectors.Vocab at 0x7f46efd3c250>,
#  'grill': <gensim.models.keyedvectors.Vocab at 0x7f46efd3c1d0>,
#  'chees': <gensim.models.keyedvectors.Vocab at 0x7f46efd3cc50>,
#  'ham': <gensim.models.keyedvectors.Vocab at 0x7f46efd3ca10>,
#  'wheat': <gensim.models.keyedvectors.Vocab at 0x7f46efd3cf10>,
#  'lunch': <gensim.models.keyedvectors.Vocab at 0x7f46efd3cd90>,
#  'famili': <gensim.models.keyedvectors.Vocab at 0x7f46efd3c850>,
#  'broken': <gensim.models.keyedvectors.Vocab at 0x7f46efd3ca90>,
#  'condit': <gensim.models.keyedvectors.Vocab at 0x7f46efd3cb50>,
#  'request': <gensim.models.keyedvectors.Vocab at 0x7f46efd3cd10>,
#  'here': <gensim.models.keyedvectors.Vocab at 0x7f46efd3cf50>,
#  'payment': <gensim.models.keyedvectors.Vocab at 0x7f46efd3cb90>,
#  'benefit': <gensim.models.keyedvectors.Vocab at 0x7f46efd3c790>,
#  'disabl': <gensim.models.keyedvectors.Vocab at 0x7f46efd3c990>,
#  'submit': <gensim.models.keyedvectors.Vocab at 0x7f46efd3cbd0>,
#  'write': <gensim.models.keyedvectors.Vocab at 0x7f46efd3c8d0>,
#  'confirm': <gensim.models.keyedvectors.Vocab at 0x7f46efdbfa50>,
#  'necessari': <gensim.models.keyedvectors.Vocab at 0x7f46efdbf550>,
#  'japanes': <gensim.models.keyedvectors.Vocab at 0x7f46efdbfc90>,
#  'sentenc': <gensim.models.keyedvectors.Vocab at 0x7f46efdbf710>,
#  'bet': <gensim.models.keyedvectors.Vocab at 0x7f46efdbfad0>,
#  'sign': <gensim.models.keyedvectors.Vocab at 0x7f46efdbf610>,
#  'began': <gensim.models.keyedvectors.Vocab at 0x7f46efdbfc50>,
#  'kill': <gensim.models.keyedvectors.Vocab at 0x7f46efdbf290>,
#  'star': <gensim.models.keyedvectors.Vocab at 0x7f46efdbfdd0>,
#  'clear': <gensim.models.keyedvectors.Vocab at 0x7f46efdbf350>,
#  '8': <gensim.models.keyedvectors.Vocab at 0x7f46efdbf310>,
#  'rift': <gensim.models.keyedvectors.Vocab at 0x7f46efdbfa10>,
#  'diablo': <gensim.models.keyedvectors.Vocab at 0x7f46efdbf690>,
#  'greater': <gensim.models.keyedvectors.Vocab at 0x7f46efdbf090>,
#  '45': <gensim.models.keyedvectors.Vocab at 0x7f46efdbfa90>,
#  'notic': <gensim.models.keyedvectors.Vocab at 0x7f46efdbf650>,
#  'gone': <gensim.models.keyedvectors.Vocab at 0x7f46efdbfed0>,
#  'depart': <gensim.models.keyedvectors.Vocab at 0x7f46efdbfd50>,
#  'happen': <gensim.models.keyedvectors.Vocab at 0x7f46efdbfe90>,
#  'son': <gensim.models.keyedvectors.Vocab at 0x7f46efdbfb10>,
#  'commiss': <gensim.models.keyedvectors.Vocab at 0x7f46efdbf590>,
#  '9': <gensim.models.keyedvectors.Vocab at 0x7f46efdbfbd0>,
#  'interview': <gensim.models.keyedvectors.Vocab at 0x7f46efdbf490>,
#  'amazon': <gensim.models.keyedvectors.Vocab at 0x7f46efdbf2d0>,
#  'extra': <gensim.models.keyedvectors.Vocab at 0x7f46efdbf390>,
#  'hire': <gensim.models.keyedvectors.Vocab at 0x7f46efd62750>,
#  'littl': <gensim.models.keyedvectors.Vocab at 0x7f46efd62d10>,
#  'bit': <gensim.models.keyedvectors.Vocab at 0x7f46efd62650>,
#  'thought': <gensim.models.keyedvectors.Vocab at 0x7f46efd62510>,
#  'dent': <gensim.models.keyedvectors.Vocab at 0x7f46efd620d0>,
#  'custom': <gensim.models.keyedvectors.Vocab at 0x7f46efd62990>,
#  '1000': <gensim.models.keyedvectors.Vocab at 0x7f46efd62f90>,
#  'premium': <gensim.models.keyedvectors.Vocab at 0x7f46efd62e10>,
#  'nephew': <gensim.models.keyedvectors.Vocab at 0x7f46efd62350>,
#  '500': <gensim.models.keyedvectors.Vocab at 0x7f46efd62250>,
#  'hurt': <gensim.models.keyedvectors.Vocab at 0x7f46efd627d0>,
#  'cheaper': <gensim.models.keyedvectors.Vocab at 0x7f46efd624d0>,
#  'origin': <gensim.models.keyedvectors.Vocab at 0x7f46efd62a50>,
#  'servic': <gensim.models.keyedvectors.Vocab at 0x7f46efd62b10>,
#  'significantli': <gensim.models.keyedvectors.Vocab at 0x7f46efd62590>,
#  'reduc': <gensim.models.keyedvectors.Vocab at 0x7f46efd629d0>,
#  'caus': <gensim.models.keyedvectors.Vocab at 0x7f46efd62fd0>,
#  'deal': <gensim.models.keyedvectors.Vocab at 0x7f46efd622d0>,
#  'although': <gensim.models.keyedvectors.Vocab at 0x7f46efd623d0>,
#  'signific': <gensim.models.keyedvectors.Vocab at 0x7f46efd62950>,
#  'basement': <gensim.models.keyedvectors.Vocab at 0x7f46efd62810>,
#  'truck': <gensim.models.keyedvectors.Vocab at 0x7f46efd62d90>,
#  'fifti': <gensim.models.keyedvectors.Vocab at 0x7f46efd62a90>,
#  'percent': <gensim.models.keyedvectors.Vocab at 0x7f46efd62dd0>,
#  'appoint': <gensim.models.keyedvectors.Vocab at 0x7f46efd621d0>,
#  'eye': <gensim.models.keyedvectors.Vocab at 0x7f46efd62110>,
#  'doctor': <gensim.models.keyedvectors.Vocab at 0x7f46efd62cd0>,
#  'glass': <gensim.models.keyedvectors.Vocab at 0x7f46efd62b90>,
#  'outstand': <gensim.models.keyedvectors.Vocab at 0x7f46efd62c50>,
#  'worker': <gensim.models.keyedvectors.Vocab at 0x7f46efd6d610>,
#  'ate': <gensim.models.keyedvectors.Vocab at 0x7f46efd6d550>,
#  'materi': <gensim.models.keyedvectors.Vocab at 0x7f46efd6dd90>,
#  'bathroom': <gensim.models.keyedvectors.Vocab at 0x7f46efd6d310>,
#  'overdu': <gensim.models.keyedvectors.Vocab at 0x7f46efd6d050>,
#  'nomin': <gensim.models.keyedvectors.Vocab at 0x7f46efd6d4d0>,
#  'leadership': <gensim.models.keyedvectors.Vocab at 0x7f46efd6db50>,
#  'care': <gensim.models.keyedvectors.Vocab at 0x7f46efd6d890>,
#  'explor': <gensim.models.keyedvectors.Vocab at 0x7f46efd6dcd0>,
#  'trip': <gensim.models.keyedvectors.Vocab at 0x7f46efd6dbd0>,
#  'modif': <gensim.models.keyedvectors.Vocab at 0x7f46efd6d6d0>,
#  'should': <gensim.models.keyedvectors.Vocab at 0x7f46efd6d410>,
#  'manufactur': <gensim.models.keyedvectors.Vocab at 0x7f46efd6d8d0>,
#  'process': <gensim.models.keyedvectors.Vocab at 0x7f46efd6df50>,
#  'particip': <gensim.models.keyedvectors.Vocab at 0x7f46efd6dc10>,
#  'valu': <gensim.models.keyedvectors.Vocab at 0x7f46efd6dc90>,
#  'chanc': <gensim.models.keyedvectors.Vocab at 0x7f46efd6db90>,
#  'catch': <gensim.models.keyedvectors.Vocab at 0x7f46efd6d510>,
#  'concentr': <gensim.models.keyedvectors.Vocab at 0x7f46efd6d090>,
#  'these': <gensim.models.keyedvectors.Vocab at 0x7f46efd6ddd0>,
#  'under': <gensim.models.keyedvectors.Vocab at 0x7f46efd6dad0>,
#  'everyth': <gensim.models.keyedvectors.Vocab at 0x7f46efd6df90>,
#  'wrote': <gensim.models.keyedvectors.Vocab at 0x7f46efd6d710>,
#  'short': <gensim.models.keyedvectors.Vocab at 0x7f46efd6dd10>,
#  'essay': <gensim.models.keyedvectors.Vocab at 0x7f46efd6d1d0>,
#  '>': <gensim.models.keyedvectors.Vocab at 0x7f46efd6d250>,
#  'word': <gensim.models.keyedvectors.Vocab at 0x7f46efd6d5d0>,
#  'prize': <gensim.models.keyedvectors.Vocab at 0x7f46efd6d150>,
#  'pool': <gensim.models.keyedvectors.Vocab at 0x7f46efd6ded0>,
#  'chapter': <gensim.models.keyedvectors.Vocab at 0x7f46efdcab50>,
#  'android': <gensim.models.keyedvectors.Vocab at 0x7f46efdcabd0>,
#  'terribl': <gensim.models.keyedvectors.Vocab at 0x7f46efdcaa50>,
#  'author': <gensim.models.keyedvectors.Vocab at 0x7f46efdca110>,
#  'solut': <gensim.models.keyedvectors.Vocab at 0x7f46efdca650>,
#  'describ': <gensim.models.keyedvectors.Vocab at 0x7f46efdca9d0>,
#  ...}

# %% [markdown]
# ### Modell evaluieren

# %% [markdown]
# #### "scharfes Hinsehen"

# %%
model.wv.most_similar('love')
# Out:
# [('like', 0.5175316333770752),
#  ('childhood', 0.4417549669742584),
#  ('cute', 0.40941429138183594),
#  ('miss', 0.4085070490837097),
#  ('excit', 0.4067125916481018),
#  ('know', 0.4039749503135681),
#  ('terrif', 0.397244393825531),
#  ('sweet', 0.3965001404285431),
#  ('young', 0.39443838596343994),
#  ('never', 0.38973623514175415)]

# %%
model.wv.most_similar('brother')
# Out:
# [('cousin', 0.7185249924659729),
#  ('sister', 0.605430006980896),
#  ('father', 0.6039519309997559),
#  ('dad', 0.5944823622703552),
#  ('nephew', 0.5799951553344727),
#  ('mom', 0.5754165649414062),
#  ('son', 0.5563855171203613),
#  ('girlfriend', 0.5534058809280396),
#  ('friend', 0.5523203015327454),
#  ('mother', 0.5451760292053223)]

# %%
model.wv.most_similar('famili')
# Out:
# [('girlfriend', 0.5021774172782898),
#  ('weekend', 0.49192479252815247),
#  ('time', 0.4840264320373535),
#  ('wife', 0.47207337617874146),
#  ('rel', 0.4620027542114258),
#  ('parti', 0.46109408140182495),
#  ('husband', 0.4572964608669281),
#  ('cousin', 0.449217826128006),
#  ('sister', 0.433441698551178),
#  ('partner', 0.4314582645893097)]

# %%
# Compute ranks of similar documents
ranks = []
second_ranks = []
print(len(model.docvecs))
for doc_id in range(len(train_corpus)):
    inferred_vector = model.infer_vector(train_corpus[doc_id].words)
    sims = model.docvecs.most_similar([inferred_vector], topn=(len(model.docvecs)))

    rank = [docid for docid, sim in sims].index(doc_id)
    ranks.append(rank)

    second_ranks.append(sims[1])
# Out:
# 14083

# %%
counter = Counter(ranks)
print(counter)
# Out:
# Counter({0: 11987, 1: 437, 2: 220, 3: 120, 4: 87, 5: 74, 6: 56, 7: 51, 8: 48, 10: 35, 11: 25, 9: 25, 14: 22, 18: 19, 13: 17, 20: 17, 12: 17, 17: 17, 24: 15, 16: 14, 27: 14, 31: 14, 19: 13, 15: 12, 21: 11, 26: 11, 55: 10, 28: 10, 39: 10, 29: 10, 30: 9, 25: 9, 44: 9, 32: 9, 56: 9, 33: 9, 36: 9, 34: 9, 23: 8, 54: 8, 22: 8, 41: 8, 37: 7, 61: 7, 50: 7, 42: 6, 53: 6, 43: 6, 67: 6, 52: 6, 35: 6, 84: 6, 64: 5, 70: 5, 99: 5, 71: 5, 62: 5, 46: 5, 45: 5, 98: 5, 168: 4, 60: 4, 58: 4, 94: 4, 109: 4, 195: 4, 144: 4, 130: 4, 139: 4, 119: 4, 48: 4, 77: 4, 75: 4, 88: 4, 117: 4, 76: 3, 90: 3, 59: 3, 66: 3, 105: 3, 151: 3, 57: 3, 163: 3, 91: 3, 65: 3, 72: 3, 165: 3, 145: 3, 40: 3, 38: 3, 92: 3, 69: 3, 89: 3, 102: 3, 184: 3, 82: 3, 125: 3, 150: 3, 170: 3, 95: 3, 78: 3, 253: 3, 51: 3, 103: 3, 344: 3, 296: 3, 187: 3, 68: 3, 133: 3, 80: 3, 79: 3, 113: 3, 106: 3, 202: 2, 124: 2, 300: 2, 222: 2, 204: 2, 179: 2, 406: 2, 192: 2, 47: 2, 104: 2, 116: 2, 85: 2, 132: 2, 211: 2, 256: 2, 122: 2, 73: 2, 352: 2, 161: 2, 241: 2, 272: 2, 312: 2, 381: 2, 200: 2, 162: 2, 370: 2, 194: 2, 207: 2, 169: 2, 306: 2, 181: 2, 712: 2, 245: 2, 174: 2, 175: 2, 96: 2, 273: 2, 114: 2, 443: 2, 100: 2, 446: 2, 171: 2, 146: 2, 101: 2, 475: 2, 97: 2, 81: 2, 1176: 2, 236: 2, 199: 1, 143: 1, 212: 1, 87: 1, 513: 1, 418: 1, 310: 1, 213: 1, 973: 1, 530: 1, 265: 1, 696: 1, 172: 1, 246: 1, 258: 1, 779: 1, 441: 1, 625: 1, 711: 1, 1713: 1, 287: 1, 294: 1, 998: 1, 160: 1, 416: 1, 173: 1, 542: 1, 191: 1, 295: 1, 594: 1, 277: 1, 332: 1, 234: 1, 615: 1, 136: 1, 292: 1, 356: 1, 137: 1, 230: 1, 115: 1, 148: 1, 315: 1, 683: 1, 952: 1, 249: 1, 269: 1, 366: 1, 201: 1, 108: 1, 656: 1, 259: 1, 190: 1, 304: 1, 459: 1, 635: 1, 152: 1, 301: 1, 815: 1, 791: 1, 549: 1, 206: 1, 250: 1, 74: 1, 557: 1, 134: 1, 325: 1, 362: 1, 120: 1, 825: 1, 271: 1, 183: 1, 284: 1, 203: 1, 581: 1, 227: 1, 308: 1, 588: 1, 426: 1, 342: 1, 373: 1, 196: 1, 216: 1, 276: 1, 93: 1, 512: 1, 663: 1, 393: 1, 809: 1, 147: 1, 110: 1, 349: 1, 584: 1, 185: 1, 423: 1, 330: 1, 617: 1, 718: 1, 323: 1, 189: 1, 343: 1, 317: 1, 358: 1, 676: 1, 290: 1, 956: 1, 503: 1, 1167: 1, 566: 1, 278: 1, 131: 1, 242: 1, 401: 1, 107: 1, 537: 1, 244: 1, 220: 1, 486: 1, 355: 1, 438: 1, 880: 1, 1147: 1, 329: 1, 838: 1, 424: 1, 524: 1, 186: 1, 251: 1, 128: 1, 129: 1, 636: 1, 1523: 1, 1501: 1, 225: 1, 849: 1, 138: 1, 476: 1, 123: 1, 1034: 1, 257: 1, 1273: 1, 1145: 1, 403: 1, 1385: 1, 535: 1, 1467: 1, 613: 1, 870: 1, 1040: 1, 820: 1, 922: 1, 2180: 1, 86: 1, 682: 1, 1627: 1, 691: 1, 456: 1, 415: 1, 859: 1, 2398: 1, 1171: 1, 1036: 1, 2529: 1, 1440: 1, 864: 1, 811: 1, 328: 1, 675: 1, 188: 1, 467: 1, 83: 1, 827: 1, 320: 1, 531: 1, 142: 1, 421: 1, 135: 1, 958: 1, 255: 1, 319: 1, 140: 1, 232: 1, 121: 1, 218: 1, 49: 1, 823: 1, 462: 1})

# %%
print('Document ({}): «{}»\n'.format(doc_id, ' '.join(train_corpus[doc_id].words)))
print(u'SIMILAR/DISSIMILAR DOCS PER MODEL %s:\n' % model)
for label, index in [('MOST', 0), ('SECOND-MOST', 1), ('MEDIAN', len(sims)//2), ('LEAST', len(sims) - 1)]:
    print(u'%s %s: «%s»\n' % (label, sims[index], ' '.join(train_corpus[sims[index][0]].words)))
# Out:
# Document (14082): «last night my roommat came home from work and told me he 's up for go to the mountain for the weekend to hike and explor . i live for be outdoor with natur . i 'll be excit until it 's time to come home .»
#
# SIMILAR/DISSIMILAR DOCS PER MODEL Doc2Vec(dm/m,d100,n5,w5,mc2,s0.001,t3):
#
# MOST (14082, 0.8840101957321167): «last night my roommat came home from work and told me he 's up for go to the mountain for the weekend to hike and explor . i live for be outdoor with natur . i 'll be excit until it 's time to come home .»
#
# SECOND-MOST (11119, 0.6069707274436951): «i think it 's time to be happi again .»
#
# MEDIAN (7445, 0.10064682364463806): «i met a girl and end up go on a date with her to the mall in town and after we went to eat at a nice restaur .»
#
# LEAST (3598, -0.3655965328216553): «i sign a contract with my first photographi client that wa not a rel or friend .»

# %%
import random
# Pick a random document from the test corpus and infer a vector from the model
doc_id = random.randint(0, len(train_corpus) - 1)
inferred_vector = model.infer_vector(train_corpus[doc_id].words)
sims = model.docvecs.most_similar([inferred_vector], topn=len(model.docvecs))

# Compare and print the most/median/least similar documents from the train corpus
print('Test Document ({}): «{}»\n'.format(doc_id, ' '.join(train_corpus[doc_id].words)))
print(u'SIMILAR/DISSIMILAR DOCS PER MODEL %s:\n' % model)
for label, index in [('MOST', 0), ('MEDIAN', len(sims)//2), ('LEAST', len(sims) - 1)]:
    print(u'%s %s: «%s»\n' % (label, sims[index], ' '.join(train_corpus[sims[index][0]].words)))
# Out:
# Test Document (4829): «my sister had success gall bladder surgeri with no issu .»
#
# SIMILAR/DISSIMILAR DOCS PER MODEL Doc2Vec(dm/m,d100,n5,w5,mc2,s0.001,t3):
#
# MOST (4829, 0.8424397706985474): «my sister had success gall bladder surgeri with no issu .»
#
# MEDIAN (12947, 0.4293534457683563): «there wa a new episod of my current favorit show .»
#
# LEAST (3217, -0.2881014943122864): «i fix my older laptop and made it function again .»

# %% [markdown]
# #### Berechnung der Ähnlichkeit von Dokumenten desselben Genres

# %%
def get_doc_index(sims, train_tagged):
    result = []
    for sim in sims:
        for k,v in train_tagged.items():
            for i in range(len(v)):
                if v[i][1][0] == sim[0]:
                    result.append((k, v[i][0],sim[1]))
    return result

# %%
def assign_genre_combination(df):
    for i, row in df.iterrows():
        genre = df.iloc[0,7]
            # print((df.iloc[i,6]))
        df.at[i, 'genre_comb'] = str(genre)+'_'+str(df.iloc[i,7])
    return df

# %%
def most_similar_doc(songs, sims, train_tagged):
    match = []
    similarity = []
    for i, row in happy.iterrows():
        for res in get_doc_index(sims, train_tagged):
            if res[1]==row.stemmed:
                match.append(row)
                similarity.append(res[2])
    match_df = pd.DataFrame(match)
    match_df['similarity'] = similarity
    match_df.sort_values(by=['similarity'], inplace=True, ascending=False)
    match_df = match_df.reset_index()
    # print(match_df)
    match_df = assign_genre_combination(match_df)

    return match_df

# corpus = train_corpus + test_corpus

# match_df = most_similar_doc(happy, sims, train_tagged)
# match_df
